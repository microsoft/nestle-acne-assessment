# %% [markdown]
# ## Score a new selfie image and evaluate the acne severity of the face
# Given a set of selfie images, this script is used to score the acne severity levels of the selfie face images. We score each skin patch from the selfie and the average score is chosen as the image label.
#
# The scoring pipelines have the following four steps:
# 1. Extract skin patches
# 2. Predict the label for each skin patch
#  *  Extract features from CNTK pretrained model
#  *  Score the features using the trained full connected neural network model
# 3. infer the whole face label based on predicted labels of the skin patches from that selfie image. The inferred labels of the entire selfie images in the test directory are output to a csv file.
# 4. (Optional) If you also have a csv file with the ground truth labels of the test images, we also compare the predicted label and the ground truth labels, and calculate the RMSE on the golden set.
#
# ***Note***: With the model you trained on Step 3, where random seed = 5 for splitting the training images into training and validation, and initializing the weights of the neural network models, you should get ***RMSE = 0.4819*** on golden set images.

# %% [markdown]
# ## Prerequisites
#
# ### Test images
# - Test images should be put in a directory on the machine, and provide the path to this directory to parameter image\_path.
# - (***Optional***) Ground truth labels of the test images should be put in a csv file with a headerline, and two columns: Image_Name, Ground_Truth. If this file is None, calculating the RMSE on the test images will be skipped.
#
# ### Python, Python libraries and self-defined Python Script
# - Python 3.5 or later version
# - CNTK, PIL
# - getPatches.py to extract patches from a selfie (modified from ***[Step 1. Extract Forehead, cheeks, and chin skin patches from raw images using facial landmark model and One Eye model](../01_DataPrep/Step 1. Extract Forehead, cheeks, and chin skin patches from raw images using facial landmark model and One Eye model.ipynb)***)
# ***Note*** You need to mofidy the path to the pretrained landmark model and the Cascade Eye model in the getPatches.py file.
#
# ### Pretrained models
# - [Frontal face landmark model](https://github.com/AKSHAYUBHAT/TensorFace/blob/master/openface/models/dlib/shape_predictor_68_face_landmarks.dat) in the same directory as this jupyter notebook.
# - [One Eye model](https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml) in the same directory as this jupyter notebook.
# - [ResNet152\_ImageNet\_Caffe.model](https://www.cntk.ai/Models/Caffe_Converted/ResNet152_ImageNet_Caffe.model)
# - Trained full connected neural network regression model from ***[Step 3. Training_Pipeline](Step3_Training_Pipeline.ipynb)***

# %% [markdown]
# ## Parameters

# %%
pretrained_model_name = 'ResNet152_ImageNet_Caffe.model'
pretrained_model_path = '../models'
pretrained_node_name = 'pool5' 

label_mapping = {1: '1-Clear', 2: '2-Almost Clear', 3: '3-Mild', 4: '4-Moderate', 5: '5-Severe'}

img_path = '<path to test images>'
test_ground_truth = '<csv file for ground truth of test images>' #If None, calculating RMSE on test set will be skipped
result_file = '<csv file to store predicted labels of test images>'
patch_path = '<path to test images path>'
regression_model_path = '../models/cntk_regression.dat'
eye_cascade_model = '../models/haarcascade_eye.xml'

image_height = 224 # Here are the image height and width that the skin patches of the testing selfie are going to be resized to.
image_width  = 224 # They have to be the same as the ResNet-152 model requirement.
num_channels = 3

# %%
from __future__ import print_function
import os
from os import listdir
from os.path import join, isfile, splitext
import numpy as np
import pandas as pd
import cntk as C
from PIL import Image
import pickle
import time
import json
from cntk import load_model, combine
import cntk.io.transforms as xforms
from cntk.logging import graph
from cntk.logging.graph import get_node_outputs
import getPatches
import cv2

# %% [markdown]
# ## Extract Skin Patches
#
# In the scoring pipeline, the first step is to extract forehead, left cheek, right cheek, and chin skin patches from the original selfie images. The skin patch images are going to be saved in the directory specified in variable patch\_path.
#
# During this skin patch extraction process, a facial landmark model will be first applied. If face is detected by this model, skin patches will be extracted. If face is not detected by the landmark model, OneEye model will be applied to detect the location of a single eye. Then, forehead and cheek will be extracted based on the eye location.
#
# If neither landmark nor the OneEye model works, the entire selfie will be used to make predictions.
#
# Landmark needs to see both eyes open from the camera. OneEye model works if there is only one open eye identified. Skin patches can be extracted more accurately based on landmark model. So, if possible, we encourage users to face the camera directly with both eyes opened.
#
# Keep in mind, depending on the angle of the face facing the camera, this step might result in 1, 2, 3, or 4 skin patch images.

# %%
# get the dimension of each patch of images in the testing image directory
dimension_dict = dict()
imageFiles = [f for f in listdir(img_path) if isfile(join(img_path, f))]
eye_cascade =  cv2.CascadeClassifier(eye_cascade_model)
for imagefile in imageFiles:
    dim = getPatches.extract_patches(join(img_path, imagefile), {}, patch_path, eye_cascade) #extract_patches function is defined in getPatches.py
    dimension_dict[imagefile] = dim
# Out:
# forehead dim (x_min, x_max, y_min, y_max): 709,1304, 637, 882
# chin dim (x_min, x_max, y_min, y_max): 911,1101, 1541, 1700
# right cheek dim (x_min, x_max, y_min, y_max): 682,805, 1118, 1640
# left cheek dim (x_min, x_max, y_min, y_max): 1101,1343, 1111, 1640
# forehead dim (x_min, x_max, y_min, y_max): 1866,3253, 403, 860
# chin dim (x_min, x_max, y_min, y_max): 2349,2790, 2090, 2385
# right cheek dim (x_min, x_max, y_min, y_max): 1790,2127, 1258, 2270
# left cheek dim (x_min, x_max, y_min, y_max): 2790,3377, 1248, 2269
# forehead dim (x_min, x_max, y_min, y_max): 862,2062, 1277, 1690
# chin dim (x_min, x_max, y_min, y_max): 1266,1656, 2755, 3069
# right cheek dim (x_min, x_max, y_min, y_max): 827,1074, 1928, 2953
# left cheek dim (x_min, x_max, y_min, y_max): 1656,2129, 1931, 2953
# forehead dim (x_min, x_max, y_min, y_max): 1055,1678, 614, 862
# chin dim (x_min, x_max, y_min, y_max): 1313,1504, 1500, 1690
# right cheek dim (x_min, x_max, y_min, y_max): 849,1212, 1043, 1624
# forehead dim (x_min, x_max, y_min, y_max): 261,693, 86, 227
# chin dim (x_min, x_max, y_min, y_max): 403,545, 602, 700
# right cheek dim (x_min, x_max, y_min, y_max): 254,334, 335, 662
# left cheek dim (x_min, x_max, y_min, y_max): 545,703, 336, 663
# forehead dim (x_min, x_max, y_min, y_max): 90,218, 27, 74
# chin dim (x_min, x_max, y_min, y_max): 141,184, 191, 233
# right cheek dim (x_min, x_max, y_min, y_max): 72,122, 110, 220
# forehead dim (x_min, x_max, y_min, y_max): 795,2076, 137, 558
# chin dim (x_min, x_max, y_min, y_max): 1225,1662, 1685, 1963
# right cheek dim (x_min, x_max, y_min, y_max): 814,1016, 974, 1862
# left cheek dim (x_min, x_max, y_min, y_max): 1662,2127, 944, 1859
# forehead dim (x_min, x_max, y_min, y_max): 518,1731, 599, 1056
# chin dim (x_min, x_max, y_min, y_max): 920,1315, 2306, 2580
# right cheek dim (x_min, x_max, y_min, y_max): 522,728, 1489, 2469
# left cheek dim (x_min, x_max, y_min, y_max): 1315,1834, 1426, 2462
# forehead dim (x_min, x_max, y_min, y_max): 734,1790, 724, 1074
# chin dim (x_min, x_max, y_min, y_max): 1103,1415, 1980, 2241
# right cheek dim (x_min, x_max, y_min, y_max): 679,934, 1318, 2147
# left cheek dim (x_min, x_max, y_min, y_max): 1415,1793, 1388, 2153
# forehead dim (x_min, x_max, y_min, y_max): 1553,2684, 569, 967
# chin dim (x_min, x_max, y_min, y_max): 1945,2316, 2033, 2296
# right cheek dim (x_min, x_max, y_min, y_max): 1525,1765, 1322, 2197
# left cheek dim (x_min, x_max, y_min, y_max): 2316,2737, 1283, 2193
# forehead dim (x_min, x_max, y_min, y_max): 805,2227, 676, 1196
# chin dim (x_min, x_max, y_min, y_max): 1280,1737, 2531, 2932
# right cheek dim (x_min, x_max, y_min, y_max): 791,1049, 1543, 2790
# left cheek dim (x_min, x_max, y_min, y_max): 1737,2303, 1529, 2789
# forehead dim (x_min, x_max, y_min, y_max): 242,445, 92, 157
# chin dim (x_min, x_max, y_min, y_max): 310,378, 331, 376
# right cheek dim (x_min, x_max, y_min, y_max): 238,280, 206, 358
# left cheek dim (x_min, x_max, y_min, y_max): 378,445, 209, 359
# forehead dim (x_min, x_max, y_min, y_max): 1733,3328, 113, 715
# chin dim (x_min, x_max, y_min, y_max): 2258,2744, 2286, 2723
# right cheek dim (x_min, x_max, y_min, y_max): 1673,1979, 1184, 2566
# left cheek dim (x_min, x_max, y_min, y_max): 2744,3431, 1201, 2568
# forehead dim (x_min, x_max, y_min, y_max): 776,1418, 399, 631
# chin dim (x_min, x_max, y_min, y_max): 1006,1190, 1236, 1405
# right cheek dim (x_min, x_max, y_min, y_max): 749,902, 779, 1341
# left cheek dim (x_min, x_max, y_min, y_max): 1190,1441, 780, 1341
# forehead dim (x_min, x_max, y_min, y_max): 807,1377, 412, 621
# chin dim (x_min, x_max, y_min, y_max): 1011,1177, 1170, 1320
# right cheek dim (x_min, x_max, y_min, y_max): 794,920, 756, 1262
# left cheek dim (x_min, x_max, y_min, y_max): 1177,1405, 754, 1262
# forehead dim (x_min, x_max, y_min, y_max): 385,865, 154, 325
# chin dim (x_min, x_max, y_min, y_max): 543,699, 764, 896
# right cheek dim (x_min, x_max, y_min, y_max): 374,468, 463, 852
# left cheek dim (x_min, x_max, y_min, y_max): 699,880, 461, 851
# forehead dim (x_min, x_max, y_min, y_max): 474,810, 365, 503
# chin dim (x_min, x_max, y_min, y_max): 616,720, 841, 965
# right cheek dim (x_min, x_max, y_min, y_max): 369,558, 614, 929
# forehead dim (x_min, x_max, y_min, y_max): 897,1511, 301, 519
# chin dim (x_min, x_max, y_min, y_max): 1107,1294, 1073, 1247
# right cheek dim (x_min, x_max, y_min, y_max): 872,1014, 654, 1187
# left cheek dim (x_min, x_max, y_min, y_max): 1294,1546, 654, 1187
# forehead dim (x_min, x_max, y_min, y_max): 1310,1977, 420, 647
# chin dim (x_min, x_max, y_min, y_max): 1532,1733, 1208, 1406
# right cheek dim (x_min, x_max, y_min, y_max): 1270,1432, 802, 1344
# left cheek dim (x_min, x_max, y_min, y_max): 1733,2030, 835, 1348
# forehead dim (x_min, x_max, y_min, y_max): 865,1732, 298, 633
# chin dim (x_min, x_max, y_min, y_max): 1164,1428, 1523, 1751
# right cheek dim (x_min, x_max, y_min, y_max): 831,1024, 944, 1668
# left cheek dim (x_min, x_max, y_min, y_max): 1428,1856, 900, 1664
# forehead dim (x_min, x_max, y_min, y_max): 72,745, 112, 326
# chin dim (x_min, x_max, y_min, y_max): 279,484, 952, 1042
# left cheek dim (x_min, x_max, y_min, y_max): 484,811, 538, 990
# forehead dim (x_min, x_max, y_min, y_max): 1522,2672, 582, 972
# chin dim (x_min, x_max, y_min, y_max): 1935,2294, 1942, 2275
# right cheek dim (x_min, x_max, y_min, y_max): 1434,1771, 1322, 2178
# left cheek dim (x_min, x_max, y_min, y_max): 2294,2729, 1264, 2172
# forehead dim (x_min, x_max, y_min, y_max): 78,270, 140, 194
# chin dim (x_min, x_max, y_min, y_max): 145,208, 357, 375
# right cheek dim (x_min, x_max, y_min, y_max): 67,115, 257, 363
# left cheek dim (x_min, x_max, y_min, y_max): 208,271, 250, 362
# forehead dim (x_min, x_max, y_min, y_max): 439,1510, 732, 1076
# chin dim (x_min, x_max, y_min, y_max): 802,1155, 2040, 2224
# right cheek dim (x_min, x_max, y_min, y_max): 413,638, 1352, 2136
# left cheek dim (x_min, x_max, y_min, y_max): 1155,1555, 1342, 2135
# forehead dim (x_min, x_max, y_min, y_max): 423,1472, 707, 1036
# chin dim (x_min, x_max, y_min, y_max): 771,1092, 1944, 2134
# right cheek dim (x_min, x_max, y_min, y_max): 437,606, 1217, 2041
# left cheek dim (x_min, x_max, y_min, y_max): 1092,1540, 1216, 2040
# forehead dim (x_min, x_max, y_min, y_max): 392,711, 408, 514
# chin dim (x_min, x_max, y_min, y_max): 501,604, 806, 868
# right cheek dim (x_min, x_max, y_min, y_max): 388,450, 601, 840
# left cheek dim (x_min, x_max, y_min, y_max): 604,724, 591, 839
# forehead dim (x_min, x_max, y_min, y_max): 1951,3144, 898, 1276
# chin dim (x_min, x_max, y_min, y_max): 2354,2732, 2293, 2536
# right cheek dim (x_min, x_max, y_min, y_max): 1894,2162, 1570, 2437
# left cheek dim (x_min, x_max, y_min, y_max): 2732,3235, 1580, 2438
# forehead dim (x_min, x_max, y_min, y_max): 1300,2703, 328, 870
# chin dim (x_min, x_max, y_min, y_max): 1789,2236, 2393, 2677
# right cheek dim (x_min, x_max, y_min, y_max): 1296,1521, 1420, 2548
# left cheek dim (x_min, x_max, y_min, y_max): 2236,2747, 1381, 2544
# forehead dim (x_min, x_max, y_min, y_max): 1063,2278, 485, 954
# chin dim (x_min, x_max, y_min, y_max): 1549,1898, 2225, 2520
# right cheek dim (x_min, x_max, y_min, y_max): 735,1322, 1362, 2401
# forehead dim (x_min, x_max, y_min, y_max): 705,1169, 193, 370
# chin dim (x_min, x_max, y_min, y_max): 845,997, 815, 960
# right cheek dim (x_min, x_max, y_min, y_max): 670,777, 490, 912
# left cheek dim (x_min, x_max, y_min, y_max): 997,1223, 505, 914
# forehead dim (x_min, x_max, y_min, y_max): 988,2338, 0, 326
# chin dim (x_min, x_max, y_min, y_max): 1440,1861, 1618, 1944
# right cheek dim (x_min, x_max, y_min, y_max): 945,1220, 702, 1817
# left cheek dim (x_min, x_max, y_min, y_max): 1861,2445, 671, 1814
# forehead dim (x_min, x_max, y_min, y_max): 69,412, 66, 188
# chin dim (x_min, x_max, y_min, y_max): 182,298, 526, 596
# right cheek dim (x_min, x_max, y_min, y_max): 69,126, 292, 565
# left cheek dim (x_min, x_max, y_min, y_max): 298,431, 294, 565
# forehead dim (x_min, x_max, y_min, y_max): 863,1992, 840, 1189
# chin dim (x_min, x_max, y_min, y_max): 1240,1596, 2156, 2354
# right cheek dim (x_min, x_max, y_min, y_max): 821,1055, 1487, 2265
# left cheek dim (x_min, x_max, y_min, y_max): 1596,2055, 1498, 2266
# forehead dim (x_min, x_max, y_min, y_max): 428,803, 73, 193
# chin dim (x_min, x_max, y_min, y_max): 563,678, 510, 596
# right cheek dim (x_min, x_max, y_min, y_max): 404,504, 278, 563
# left cheek dim (x_min, x_max, y_min, y_max): 678,812, 295, 565
# forehead dim (x_min, x_max, y_min, y_max): 1379,2650, 605, 1095
# chin dim (x_min, x_max, y_min, y_max): 1821,2246, 2403, 2729
# right cheek dim (x_min, x_max, y_min, y_max): 1261,1605, 1488, 2603
# left cheek dim (x_min, x_max, y_min, y_max): 2246,2664, 1544, 2608
# forehead dim (x_min, x_max, y_min, y_max): 427,1214, 513, 777
# chin dim (x_min, x_max, y_min, y_max): 711,938, 1466, 1659
# right cheek dim (x_min, x_max, y_min, y_max): 383,582, 980, 1589
# left cheek dim (x_min, x_max, y_min, y_max): 938,1275, 964, 1588
# forehead dim (x_min, x_max, y_min, y_max): 351,1068, 541, 790
# chin dim (x_min, x_max, y_min, y_max): 601,820, 1432, 1622
# right cheek dim (x_min, x_max, y_min, y_max): 301,488, 973, 1556
# left cheek dim (x_min, x_max, y_min, y_max): 820,1124, 963, 1555
# forehead dim (x_min, x_max, y_min, y_max): 2151,3436, 896, 1340
# chin dim (x_min, x_max, y_min, y_max): 2588,2996, 2446, 2821
# right cheek dim (x_min, x_max, y_min, y_max): 2044,2393, 1677, 2704
# left cheek dim (x_min, x_max, y_min, y_max): 2996,3538, 1685, 2705
# forehead dim (x_min, x_max, y_min, y_max): 1473,2548, 565, 1037
# chin dim (x_min, x_max, y_min, y_max): 1763,2052, 2270, 2611
# left cheek dim (x_min, x_max, y_min, y_max): 2052,3009, 1437, 2491
# forehead dim (x_min, x_max, y_min, y_max): 91,251, 204, 267
# chin dim (x_min, x_max, y_min, y_max): 136,184, 433, 479
# left cheek dim (x_min, x_max, y_min, y_max): 184,298, 311, 462
# forehead dim (x_min, x_max, y_min, y_max): 13,385, 0, 11
# chin dim (x_min, x_max, y_min, y_max): 117,240, 399, 506
# left cheek dim (x_min, x_max, y_min, y_max): 240,439, 129, 467
# forehead dim (x_min, x_max, y_min, y_max): 1529,2410, 678, 973
# chin dim (x_min, x_max, y_min, y_max): 1829,2125, 1750, 1957
# right cheek dim (x_min, x_max, y_min, y_max): 1432,1693, 1178, 1877
# left cheek dim (x_min, x_max, y_min, y_max): 2125,2409, 1196, 1879
# forehead dim (x_min, x_max, y_min, y_max): 859,1793, 750, 1116
# chin dim (x_min, x_max, y_min, y_max): 1246,1509, 2094, 2339
# right cheek dim (x_min, x_max, y_min, y_max): 601,1075, 1406, 2243
# forehead dim (x_min, x_max, y_min, y_max): 550,2267, 653, 1210
# chin dim (x_min, x_max, y_min, y_max): 1121,1685, 2650, 3068
# right cheek dim (x_min, x_max, y_min, y_max): 478,849, 1627, 2921
# left cheek dim (x_min, x_max, y_min, y_max): 1685,2347, 1682, 2926
# forehead dim (x_min, x_max, y_min, y_max): 112,1583, 346, 898
# chin dim (x_min, x_max, y_min, y_max): 623,1078, 2410, 2739
# right cheek dim (x_min, x_max, y_min, y_max): 78,366, 1318, 2594
# left cheek dim (x_min, x_max, y_min, y_max): 1078,1598, 1313, 2593
# forehead dim (x_min, x_max, y_min, y_max): 234,511, 189, 287
# chin dim (x_min, x_max, y_min, y_max): 337,420, 530, 616
# right cheek dim (x_min, x_max, y_min, y_max): 185,284, 350, 588
# left cheek dim (x_min, x_max, y_min, y_max): 420,506, 355, 589
# forehead dim (x_min, x_max, y_min, y_max): 699,1985, 732, 1180
# chin dim (x_min, x_max, y_min, y_max): 1173,1523, 2339, 2676
# right cheek dim (x_min, x_max, y_min, y_max): 660,955, 1563, 2562
# left cheek dim (x_min, x_max, y_min, y_max): 1523,2009, 1567, 2563
# forehead dim (x_min, x_max, y_min, y_max): 49,284, 105, 197
# chin dim (x_min, x_max, y_min, y_max): 133,206, 429, 504
# right cheek dim (x_min, x_max, y_min, y_max): 40,91, 273, 480
# left cheek dim (x_min, x_max, y_min, y_max): 206,294, 264, 479
# forehead dim (x_min, x_max, y_min, y_max): 263,806, 379, 554
# chin dim (x_min, x_max, y_min, y_max): 456,618, 1003, 1138
# right cheek dim (x_min, x_max, y_min, y_max): 231,370, 692, 1092
# left cheek dim (x_min, x_max, y_min, y_max): 618,822, 696, 1093
# forehead dim (x_min, x_max, y_min, y_max): 311,1184, 331, 644
# chin dim (x_min, x_max, y_min, y_max): 621,877, 1406, 1689
# right cheek dim (x_min, x_max, y_min, y_max): 279,486, 918, 1611
# left cheek dim (x_min, x_max, y_min, y_max): 877,1239, 905, 1610
# forehead dim (x_min, x_max, y_min, y_max): 351,1531, 486, 874
# chin dim (x_min, x_max, y_min, y_max): 736,1139, 1930, 2168
# right cheek dim (x_min, x_max, y_min, y_max): 254,546, 1186, 2068
# left cheek dim (x_min, x_max, y_min, y_max): 1139,1566, 1209, 2070
# forehead dim (x_min, x_max, y_min, y_max): 1441,2660, 528, 955
# chin dim (x_min, x_max, y_min, y_max): 1866,2222, 1994, 2380
# right cheek dim (x_min, x_max, y_min, y_max): 1365,1664, 1272, 2267
# left cheek dim (x_min, x_max, y_min, y_max): 2222,2708, 1287, 2268
# Face not detected by landmarks model...
# [  896.  1585.   486.   486.]
# Right eye detected
# forehead dim (x_min, x_max, y_min, y_max): 167,1625, 856, 1342
# cheek dim (x_min, x_max, y_min, y_max): 0,1139, 2071, 3772
# forehead dim (x_min, x_max, y_min, y_max): 816,2575, 2, 614
# chin dim (x_min, x_max, y_min, y_max): 1452,1937, 2010, 2655
# right cheek dim (x_min, x_max, y_min, y_max): 766,1189, 1004, 2487
# left cheek dim (x_min, x_max, y_min, y_max): 1937,2725, 954, 2482
# forehead dim (x_min, x_max, y_min, y_max): 1361,2717, 0, 467
# chin dim (x_min, x_max, y_min, y_max): 1846,2230, 1662, 2131
# right cheek dim (x_min, x_max, y_min, y_max): 1275,1634, 789, 1994
# left cheek dim (x_min, x_max, y_min, y_max): 2230,2836, 768, 1992
# forehead dim (x_min, x_max, y_min, y_max): 1436,2361, 568, 884
# chin dim (x_min, x_max, y_min, y_max): 1775,2056, 1687, 1940
# right cheek dim (x_min, x_max, y_min, y_max): 1367,1625, 1159, 1860
# left cheek dim (x_min, x_max, y_min, y_max): 2056,2417, 1114, 1855
# forehead dim (x_min, x_max, y_min, y_max): 201,726, 52, 243
# chin dim (x_min, x_max, y_min, y_max): 372,542, 740, 880
# right cheek dim (x_min, x_max, y_min, y_max): 187,290, 409, 832
# left cheek dim (x_min, x_max, y_min, y_max): 542,736, 421, 833
# forehead dim (x_min, x_max, y_min, y_max): 673,2258, 892, 1441
# chin dim (x_min, x_max, y_min, y_max): 1213,1715, 2819, 3272
# right cheek dim (x_min, x_max, y_min, y_max): 633,991, 1901, 3132
# left cheek dim (x_min, x_max, y_min, y_max): 1715,2373, 1838, 3126
# forehead dim (x_min, x_max, y_min, y_max): 758,2093, 803, 1296
# chin dim (x_min, x_max, y_min, y_max): 1199,1634, 2660, 2940
# right cheek dim (x_min, x_max, y_min, y_max): 741,966, 1754, 2819
# left cheek dim (x_min, x_max, y_min, y_max): 1634,2136, 1756, 2819
# forehead dim (x_min, x_max, y_min, y_max): 565,1997, 553, 1061
# chin dim (x_min, x_max, y_min, y_max): 1045,1506, 2293, 2757
# right cheek dim (x_min, x_max, y_min, y_max): 532,816, 1492, 2628
# left cheek dim (x_min, x_max, y_min, y_max): 1506,2094, 1471, 2626
# forehead dim (x_min, x_max, y_min, y_max): 459,806, 138, 263
# chin dim (x_min, x_max, y_min, y_max): 575,691, 613, 681
# right cheek dim (x_min, x_max, y_min, y_max): 440,520, 374, 649
# left cheek dim (x_min, x_max, y_min, y_max): 691,817, 378, 650
# forehead dim (x_min, x_max, y_min, y_max): 194,573, 198, 336
# chin dim (x_min, x_max, y_min, y_max): 317,443, 730, 797
# right cheek dim (x_min, x_max, y_min, y_max): 199,252, 466, 763
# left cheek dim (x_min, x_max, y_min, y_max): 443,588, 460, 762
# forehead dim (x_min, x_max, y_min, y_max): 1671,2926, 1323, 1884
# chin dim (x_min, x_max, y_min, y_max): 2214,2589, 3294, 3756
# right cheek dim (x_min, x_max, y_min, y_max): 1173,2021, 2356, 3613
# forehead dim (x_min, x_max, y_min, y_max): 2218,3463, 783, 1215
# chin dim (x_min, x_max, y_min, y_max): 2652,3013, 2362, 2655
# right cheek dim (x_min, x_max, y_min, y_max): 2116,2452, 1551, 2542
# left cheek dim (x_min, x_max, y_min, y_max): 3013,3597, 1556, 2542
# forehead dim (x_min, x_max, y_min, y_max): 2081,3143, 844, 1254
# chin dim (x_min, x_max, y_min, y_max): 2491,2821, 2258, 2621
# right cheek dim (x_min, x_max, y_min, y_max): 1805,2316, 1560, 2513
# left cheek dim (x_min, x_max, y_min, y_max): 2821,3183, 1556, 2512
# forehead dim (x_min, x_max, y_min, y_max): 726,1705, 679, 1041
# chin dim (x_min, x_max, y_min, y_max): 1080,1387, 2019, 2249
# right cheek dim (x_min, x_max, y_min, y_max): 675,913, 1370, 2159
# left cheek dim (x_min, x_max, y_min, y_max): 1387,1735, 1360, 2158
# forehead dim (x_min, x_max, y_min, y_max): 2012,3197, 960, 1379
# chin dim (x_min, x_max, y_min, y_max): 2506,2841, 2452, 2778
# right cheek dim (x_min, x_max, y_min, y_max): 1713,2307, 1753, 2673
# forehead dim (x_min, x_max, y_min, y_max): 2160,3441, 899, 1352
# chin dim (x_min, x_max, y_min, y_max): 2606,2991, 2515, 2864
# right cheek dim (x_min, x_max, y_min, y_max): 2090,2414, 1709, 2746
# left cheek dim (x_min, x_max, y_min, y_max): 2991,3558, 1712, 2746
# forehead dim (x_min, x_max, y_min, y_max): 2248,3454, 878, 1262
# chin dim (x_min, x_max, y_min, y_max): 2685,3037, 2209, 2544
# right cheek dim (x_min, x_max, y_min, y_max): 2143,2483, 1545, 2442
# left cheek dim (x_min, x_max, y_min, y_max): 3037,3531, 1557, 2443
# forehead dim (x_min, x_max, y_min, y_max): 531,1664, 439, 879
# chin dim (x_min, x_max, y_min, y_max): 956,1326, 2019, 2348
# right cheek dim (x_min, x_max, y_min, y_max): 436,765, 1258, 2237
# forehead dim (x_min, x_max, y_min, y_max): 264,698, 263, 427
# chin dim (x_min, x_max, y_min, y_max): 399,549, 852, 975
# right cheek dim (x_min, x_max, y_min, y_max): 249,334, 574, 934
# left cheek dim (x_min, x_max, y_min, y_max): 549,722, 572, 934
# forehead dim (x_min, x_max, y_min, y_max): 499,1371, 651, 964
# chin dim (x_min, x_max, y_min, y_max): 807,1075, 1740, 2008
# right cheek dim (x_min, x_max, y_min, y_max): 476,667, 1184, 1924
# left cheek dim (x_min, x_max, y_min, y_max): 1075,1395, 1197, 1925
# forehead dim (x_min, x_max, y_min, y_max): 482,1427, 519, 854
# chin dim (x_min, x_max, y_min, y_max): 810,1078, 1708, 1973
# right cheek dim (x_min, x_max, y_min, y_max): 449,655, 1127, 1887
# left cheek dim (x_min, x_max, y_min, y_max): 1078,1485, 1142, 1888
# forehead dim (x_min, x_max, y_min, y_max): 592,1333, 656, 904
# chin dim (x_min, x_max, y_min, y_max): 864,1073, 1567, 1731
# right cheek dim (x_min, x_max, y_min, y_max): 564,738, 1110, 1667
# left cheek dim (x_min, x_max, y_min, y_max): 1073,1380, 1107, 1667
# forehead dim (x_min, x_max, y_min, y_max): 521,1387, 653, 944
# chin dim (x_min, x_max, y_min, y_max): 830,1077, 1731, 1915
# right cheek dim (x_min, x_max, y_min, y_max): 494,689, 1181, 1840
# left cheek dim (x_min, x_max, y_min, y_max): 1077,1430, 1177, 1839
# forehead dim (x_min, x_max, y_min, y_max): 318,640, 410, 526
# chin dim (x_min, x_max, y_min, y_max): 418,527, 828, 913
# right cheek dim (x_min, x_max, y_min, y_max): 301,372, 614, 882
# left cheek dim (x_min, x_max, y_min, y_max): 527,668, 613, 882
# forehead dim (x_min, x_max, y_min, y_max): 569,1745, 624, 1014
# chin dim (x_min, x_max, y_min, y_max): 991,1364, 2091, 2316
# right cheek dim (x_min, x_max, y_min, y_max): 549,794, 1417, 2224
# left cheek dim (x_min, x_max, y_min, y_max): 1364,1782, 1376, 2219
# forehead dim (x_min, x_max, y_min, y_max): 254,746, 278, 445
# chin dim (x_min, x_max, y_min, y_max): 421,581, 896, 1003
# right cheek dim (x_min, x_max, y_min, y_max): 234,342, 589, 961
# left cheek dim (x_min, x_max, y_min, y_max): 581,745, 588, 961
# forehead dim (x_min, x_max, y_min, y_max): 265,716, 320, 471
# chin dim (x_min, x_max, y_min, y_max): 413,558, 888, 975
# right cheek dim (x_min, x_max, y_min, y_max): 252,342, 597, 936
# left cheek dim (x_min, x_max, y_min, y_max): 558,723, 599, 936
# forehead dim (x_min, x_max, y_min, y_max): 228,733, 292, 461
# chin dim (x_min, x_max, y_min, y_max): 400,558, 928, 1027
# right cheek dim (x_min, x_max, y_min, y_max): 217,318, 611, 984
# left cheek dim (x_min, x_max, y_min, y_max): 558,737, 609, 984
# forehead dim (x_min, x_max, y_min, y_max): 587,1415, 654, 949
# chin dim (x_min, x_max, y_min, y_max): 857,1119, 1714, 1935
# right cheek dim (x_min, x_max, y_min, y_max): 574,726, 1173, 1857
# left cheek dim (x_min, x_max, y_min, y_max): 1119,1457, 1184, 1858
# forehead dim (x_min, x_max, y_min, y_max): 224,729, 307, 469
# chin dim (x_min, x_max, y_min, y_max): 397,550, 892, 1012
# right cheek dim (x_min, x_max, y_min, y_max): 212,319, 602, 970
# left cheek dim (x_min, x_max, y_min, y_max): 550,759, 598, 970
# forehead dim (x_min, x_max, y_min, y_max): 250,722, 315, 470
# chin dim (x_min, x_max, y_min, y_max): 413,558, 886, 987
# right cheek dim (x_min, x_max, y_min, y_max): 223,331, 595, 947
# left cheek dim (x_min, x_max, y_min, y_max): 558,735, 606, 948
# forehead dim (x_min, x_max, y_min, y_max): 257,698, 317, 471
# chin dim (x_min, x_max, y_min, y_max): 411,540, 873, 987
# right cheek dim (x_min, x_max, y_min, y_max): 227,334, 604, 948
# left cheek dim (x_min, x_max, y_min, y_max): 540,711, 615, 949
# forehead dim (x_min, x_max, y_min, y_max): 249,703, 291, 444
# chin dim (x_min, x_max, y_min, y_max): 407,544, 862, 954
# right cheek dim (x_min, x_max, y_min, y_max): 235,331, 572, 915
# left cheek dim (x_min, x_max, y_min, y_max): 544,728, 579, 915
# forehead dim (x_min, x_max, y_min, y_max): 498,1454, 602, 925
# chin dim (x_min, x_max, y_min, y_max): 825,1113, 1811, 2004
# right cheek dim (x_min, x_max, y_min, y_max): 459,657, 1204, 1922
# left cheek dim (x_min, x_max, y_min, y_max): 1113,1497, 1219, 1923
# forehead dim (x_min, x_max, y_min, y_max): 279,657, 381, 507
# chin dim (x_min, x_max, y_min, y_max): 410,528, 831, 929
# right cheek dim (x_min, x_max, y_min, y_max): 268,347, 611, 896
# left cheek dim (x_min, x_max, y_min, y_max): 528,679, 612, 896
# forehead dim (x_min, x_max, y_min, y_max): 270,683, 316, 478
# chin dim (x_min, x_max, y_min, y_max): 410,549, 898, 1020
# right cheek dim (x_min, x_max, y_min, y_max): 245,353, 590, 976
# left cheek dim (x_min, x_max, y_min, y_max): 549,697, 585, 976
# forehead dim (x_min, x_max, y_min, y_max): 441,1489, 595, 914
# chin dim (x_min, x_max, y_min, y_max): 818,1130, 1777, 1980
# right cheek dim (x_min, x_max, y_min, y_max): 406,661, 1189, 1899
# left cheek dim (x_min, x_max, y_min, y_max): 1130,1531, 1171, 1897
# forehead dim (x_min, x_max, y_min, y_max): 459,1445, 649, 958
# chin dim (x_min, x_max, y_min, y_max): 810,1096, 1780, 1990
# right cheek dim (x_min, x_max, y_min, y_max): 435,654, 1203, 1910
# left cheek dim (x_min, x_max, y_min, y_max): 1096,1482, 1202, 1910
# forehead dim (x_min, x_max, y_min, y_max): 295,675, 308, 454
# chin dim (x_min, x_max, y_min, y_max): 418,545, 842, 941
# right cheek dim (x_min, x_max, y_min, y_max): 278,358, 565, 902
# left cheek dim (x_min, x_max, y_min, y_max): 545,700, 566, 903
# forehead dim (x_min, x_max, y_min, y_max): 643,1607, 642, 999
# chin dim (x_min, x_max, y_min, y_max): 973,1279, 1984, 2191
# right cheek dim (x_min, x_max, y_min, y_max): 609,803, 1318, 2102
# left cheek dim (x_min, x_max, y_min, y_max): 1279,1660, 1292, 2099
# Face not detected by landmarks model...
# [1081 1040  185  185]
# Right eye detected
# forehead dim (x_min, x_max, y_min, y_max): 803,1358, 762, 947
# cheek dim (x_min, x_max, y_min, y_max): 563,1173, 1225, 1872
# forehead dim (x_min, x_max, y_min, y_max): 470,1456, 492, 846
# chin dim (x_min, x_max, y_min, y_max): 787,1099, 1782, 2029
# right cheek dim (x_min, x_max, y_min, y_max): 426,621, 1110, 1935
# left cheek dim (x_min, x_max, y_min, y_max): 1099,1483, 1106, 1935
# forehead dim (x_min, x_max, y_min, y_max): 493,1480, 641, 958
# chin dim (x_min, x_max, y_min, y_max): 820,1140, 1801, 2017
# right cheek dim (x_min, x_max, y_min, y_max): 475,659, 1169, 1930
# left cheek dim (x_min, x_max, y_min, y_max): 1140,1495, 1178, 1931
# forehead dim (x_min, x_max, y_min, y_max): 549,1437, 579, 915
# chin dim (x_min, x_max, y_min, y_max): 841,1130, 1843, 2037
# right cheek dim (x_min, x_max, y_min, y_max): 514,694, 1199, 1952
# left cheek dim (x_min, x_max, y_min, y_max): 1130,1480, 1212, 1953
# forehead dim (x_min, x_max, y_min, y_max): 518,1415, 607, 934
# chin dim (x_min, x_max, y_min, y_max): 823,1107, 1810, 2027
# right cheek dim (x_min, x_max, y_min, y_max): 486,682, 1191, 1942
# left cheek dim (x_min, x_max, y_min, y_max): 1107,1457, 1184, 1941
# forehead dim (x_min, x_max, y_min, y_max): 609,1385, 752, 1050
# chin dim (x_min, x_max, y_min, y_max): 891,1126, 1804, 2046
# right cheek dim (x_min, x_max, y_min, y_max): 571,769, 1261, 1966
# left cheek dim (x_min, x_max, y_min, y_max): 1126,1396, 1270, 1967
# forehead dim (x_min, x_max, y_min, y_max): 621,1599, 613, 1013
# chin dim (x_min, x_max, y_min, y_max): 942,1264, 1996, 2348
# right cheek dim (x_min, x_max, y_min, y_max): 595,782, 1339, 2245
# left cheek dim (x_min, x_max, y_min, y_max): 1264,1666, 1309, 2242
# forehead dim (x_min, x_max, y_min, y_max): 679,1680, 1032, 1369
# chin dim (x_min, x_max, y_min, y_max): 1009,1325, 2212, 2495
# right cheek dim (x_min, x_max, y_min, y_max): 670,861, 1617, 2406
# left cheek dim (x_min, x_max, y_min, y_max): 1325,1748, 1613, 2405
# forehead dim (x_min, x_max, y_min, y_max): 295,695, 318, 467
# chin dim (x_min, x_max, y_min, y_max): 423,559, 864, 965
# right cheek dim (x_min, x_max, y_min, y_max): 280,362, 594, 927
# left cheek dim (x_min, x_max, y_min, y_max): 559,716, 601, 928
# forehead dim (x_min, x_max, y_min, y_max): 263,714, 240, 407
# chin dim (x_min, x_max, y_min, y_max): 398,562, 838, 965
# right cheek dim (x_min, x_max, y_min, y_max): 248,333, 546, 922
# left cheek dim (x_min, x_max, y_min, y_max): 562,733, 550, 923
# forehead dim (x_min, x_max, y_min, y_max): 255,700, 251, 414
# chin dim (x_min, x_max, y_min, y_max): 400,550, 819, 958
# right cheek dim (x_min, x_max, y_min, y_max): 221,335, 556, 917
# left cheek dim (x_min, x_max, y_min, y_max): 550,727, 559, 917
# forehead dim (x_min, x_max, y_min, y_max): 477,1406, 511, 858
# chin dim (x_min, x_max, y_min, y_max): 776,1088, 1803, 2015
# right cheek dim (x_min, x_max, y_min, y_max): 480,626, 1156, 1928
# left cheek dim (x_min, x_max, y_min, y_max): 1088,1449, 1148, 1927
# forehead dim (x_min, x_max, y_min, y_max): 520,1702, 661, 1086
# chin dim (x_min, x_max, y_min, y_max): 916,1302, 2247, 2504
# right cheek dim (x_min, x_max, y_min, y_max): 502,716, 1463, 2398
# left cheek dim (x_min, x_max, y_min, y_max): 1302,1796, 1446, 2396
# forehead dim (x_min, x_max, y_min, y_max): 556,1750, 614, 1049
# chin dim (x_min, x_max, y_min, y_max): 946,1315, 2188, 2502
# right cheek dim (x_min, x_max, y_min, y_max): 516,732, 1401, 2390
# left cheek dim (x_min, x_max, y_min, y_max): 1315,1805, 1413, 2391
# forehead dim (x_min, x_max, y_min, y_max): 642,1717, 736, 1132
# chin dim (x_min, x_max, y_min, y_max): 1009,1354, 2184, 2455
# right cheek dim (x_min, x_max, y_min, y_max): 588,826, 1446, 2352
# left cheek dim (x_min, x_max, y_min, y_max): 1354,1745, 1466, 2354
# forehead dim (x_min, x_max, y_min, y_max): 187,752, 210, 408
# chin dim (x_min, x_max, y_min, y_max): 373,576, 994, 1069
# right cheek dim (x_min, x_max, y_min, y_max): 178,276, 608, 1022
# left cheek dim (x_min, x_max, y_min, y_max): 576,751, 608, 1022
# forehead dim (x_min, x_max, y_min, y_max): 216,755, 225, 421
# chin dim (x_min, x_max, y_min, y_max): 391,588, 984, 1075
# right cheek dim (x_min, x_max, y_min, y_max): 208,303, 611, 1028
# left cheek dim (x_min, x_max, y_min, y_max): 588,766, 608, 1027
# forehead dim (x_min, x_max, y_min, y_max): 672,1687, 689, 1066
# chin dim (x_min, x_max, y_min, y_max): 1021,1334, 2043, 2324
# right cheek dim (x_min, x_max, y_min, y_max): 659,850, 1439, 2233
# left cheek dim (x_min, x_max, y_min, y_max): 1334,1746, 1411, 2231
# forehead dim (x_min, x_max, y_min, y_max): 540,1593, 539, 978
# chin dim (x_min, x_max, y_min, y_max): 922,1225, 2079, 2444
# right cheek dim (x_min, x_max, y_min, y_max): 469,734, 1329, 2330
# left cheek dim (x_min, x_max, y_min, y_max): 1225,1637, 1334, 2331
# forehead dim (x_min, x_max, y_min, y_max): 605,1555, 569, 965
# chin dim (x_min, x_max, y_min, y_max): 943,1248, 1967, 2286
# right cheek dim (x_min, x_max, y_min, y_max): 563,780, 1321, 2188
# left cheek dim (x_min, x_max, y_min, y_max): 1248,1666, 1291, 2185
# forehead dim (x_min, x_max, y_min, y_max): 643,1712, 545, 971
# chin dim (x_min, x_max, y_min, y_max): 1025,1367, 2087, 2391
# right cheek dim (x_min, x_max, y_min, y_max): 456,845, 1344, 2284
# left cheek dim (x_min, x_max, y_min, y_max): 1367,1744, 1380, 2288
# forehead dim (x_min, x_max, y_min, y_max): 469,1519, 443, 833
# chin dim (x_min, x_max, y_min, y_max): 806,1175, 1889, 2135
# right cheek dim (x_min, x_max, y_min, y_max): 425,646, 1141, 2034
# left cheek dim (x_min, x_max, y_min, y_max): 1175,1590, 1134, 2033
# forehead dim (x_min, x_max, y_min, y_max): 455,1516, 431, 833
# chin dim (x_min, x_max, y_min, y_max): 786,1133, 1929, 2175
# right cheek dim (x_min, x_max, y_min, y_max): 365,608, 1142, 2070
# left cheek dim (x_min, x_max, y_min, y_max): 1133,1588, 1182, 2074
# forehead dim (x_min, x_max, y_min, y_max): 490,1483, 499, 861
# chin dim (x_min, x_max, y_min, y_max): 794,1160, 1804, 2068
# right cheek dim (x_min, x_max, y_min, y_max): 435,646, 1140, 1974
# left cheek dim (x_min, x_max, y_min, y_max): 1160,1540, 1147, 1974
# forehead dim (x_min, x_max, y_min, y_max): 510,1459, 543, 898
# chin dim (x_min, x_max, y_min, y_max): 801,1136, 1845, 2084
# right cheek dim (x_min, x_max, y_min, y_max): 465,646, 1174, 1991
# left cheek dim (x_min, x_max, y_min, y_max): 1136,1519, 1172, 1991
# forehead dim (x_min, x_max, y_min, y_max): 487,1505, 593, 972
# chin dim (x_min, x_max, y_min, y_max): 810,1173, 1974, 2237
# right cheek dim (x_min, x_max, y_min, y_max): 443,642, 1241, 2135
# left cheek dim (x_min, x_max, y_min, y_max): 1173,1547, 1244, 2136
# forehead dim (x_min, x_max, y_min, y_max): 299,643, 362, 494
# chin dim (x_min, x_max, y_min, y_max): 416,523, 837, 937
# right cheek dim (x_min, x_max, y_min, y_max): 280,358, 596, 902
# left cheek dim (x_min, x_max, y_min, y_max): 523,665, 597, 902
# forehead dim (x_min, x_max, y_min, y_max): 316,652, 373, 502
# chin dim (x_min, x_max, y_min, y_max): 427,536, 831, 935
# right cheek dim (x_min, x_max, y_min, y_max): 298,371, 597, 900
# left cheek dim (x_min, x_max, y_min, y_max): 536,678, 596, 900
# forehead dim (x_min, x_max, y_min, y_max): 279,644, 347, 490
# chin dim (x_min, x_max, y_min, y_max): 407,520, 850, 967
# right cheek dim (x_min, x_max, y_min, y_max): 261,344, 596, 929
# left cheek dim (x_min, x_max, y_min, y_max): 520,662, 594, 929
# forehead dim (x_min, x_max, y_min, y_max): 309,650, 370, 502
# chin dim (x_min, x_max, y_min, y_max): 426,533, 835, 945
# right cheek dim (x_min, x_max, y_min, y_max): 290,370, 599, 909
# left cheek dim (x_min, x_max, y_min, y_max): 533,670, 600, 910
# forehead dim (x_min, x_max, y_min, y_max): 572,1571, 682, 1025
# chin dim (x_min, x_max, y_min, y_max): 947,1259, 1991, 2169
# right cheek dim (x_min, x_max, y_min, y_max): 509,770, 1326, 2083
# forehead dim (x_min, x_max, y_min, y_max): 626,1736, 781, 1138
# chin dim (x_min, x_max, y_min, y_max): 1006,1346, 2166, 2328
# right cheek dim (x_min, x_max, y_min, y_max): 568,823, 1468, 2240
# left cheek dim (x_min, x_max, y_min, y_max): 1346,1719, 1457, 2239
# forehead dim (x_min, x_max, y_min, y_max): 608,1641, 565, 951
# chin dim (x_min, x_max, y_min, y_max): 961,1293, 1993, 2240
# right cheek dim (x_min, x_max, y_min, y_max): 525,796, 1302, 2144
# left cheek dim (x_min, x_max, y_min, y_max): 1293,1684, 1288, 2143
# forehead dim (x_min, x_max, y_min, y_max): 263,707, 241, 410
# chin dim (x_min, x_max, y_min, y_max): 405,558, 844, 974
# right cheek dim (x_min, x_max, y_min, y_max): 247,339, 556, 931
# left cheek dim (x_min, x_max, y_min, y_max): 558,737, 557, 931
# forehead dim (x_min, x_max, y_min, y_max): 266,697, 266, 431
# chin dim (x_min, x_max, y_min, y_max): 399,550, 867, 983
# right cheek dim (x_min, x_max, y_min, y_max): 246,333, 568, 941
# left cheek dim (x_min, x_max, y_min, y_max): 550,714, 578, 942
# forehead dim (x_min, x_max, y_min, y_max): 263,701, 247, 411
# chin dim (x_min, x_max, y_min, y_max): 398,554, 844, 960
# right cheek dim (x_min, x_max, y_min, y_max): 248,336, 543, 917
# left cheek dim (x_min, x_max, y_min, y_max): 554,741, 542, 917
# forehead dim (x_min, x_max, y_min, y_max): 273,718, 209, 380
# chin dim (x_min, x_max, y_min, y_max): 413,564, 803, 950
# right cheek dim (x_min, x_max, y_min, y_max): 244,344, 529, 907
# left cheek dim (x_min, x_max, y_min, y_max): 564,744, 532, 907
# forehead dim (x_min, x_max, y_min, y_max): 468,1481, 479, 845
# chin dim (x_min, x_max, y_min, y_max): 817,1124, 1741, 2067
# right cheek dim (x_min, x_max, y_min, y_max): 457,657, 1116, 1970
# left cheek dim (x_min, x_max, y_min, y_max): 1124,1504, 1104, 1969
# forehead dim (x_min, x_max, y_min, y_max): 477,1442, 555, 915
# chin dim (x_min, x_max, y_min, y_max): 795,1094, 1783, 2116
# right cheek dim (x_min, x_max, y_min, y_max): 485,650, 1175, 2020
# left cheek dim (x_min, x_max, y_min, y_max): 1094,1475, 1172, 2020
# forehead dim (x_min, x_max, y_min, y_max): 493,1433, 519, 880
# chin dim (x_min, x_max, y_min, y_max): 806,1100, 1727, 2085
# right cheek dim (x_min, x_max, y_min, y_max): 487,664, 1151, 1990
# left cheek dim (x_min, x_max, y_min, y_max): 1100,1480, 1133, 1988
# forehead dim (x_min, x_max, y_min, y_max): 449,1423, 494, 842
# chin dim (x_min, x_max, y_min, y_max): 788,1075, 1771, 2002
# right cheek dim (x_min, x_max, y_min, y_max): 402,624, 1129, 1913
# left cheek dim (x_min, x_max, y_min, y_max): 1075,1477, 1143, 1914
# forehead dim (x_min, x_max, y_min, y_max): 526,1441, 481, 790
# chin dim (x_min, x_max, y_min, y_max): 856,1113, 1629, 1822
# right cheek dim (x_min, x_max, y_min, y_max): 467,703, 1043, 1742
# left cheek dim (x_min, x_max, y_min, y_max): 1113,1457, 1059, 1744
# forehead dim (x_min, x_max, y_min, y_max): 556,1410, 638, 937
# chin dim (x_min, x_max, y_min, y_max): 849,1097, 1746, 1936
# right cheek dim (x_min, x_max, y_min, y_max): 502,709, 1185, 1859
# left cheek dim (x_min, x_max, y_min, y_max): 1097,1452, 1201, 1861
# forehead dim (x_min, x_max, y_min, y_max): 626,1329, 652, 895
# chin dim (x_min, x_max, y_min, y_max): 873,1074, 1546, 1707
# right cheek dim (x_min, x_max, y_min, y_max): 586,757, 1108, 1646
# left cheek dim (x_min, x_max, y_min, y_max): 1074,1372, 1108, 1646
# forehead dim (x_min, x_max, y_min, y_max): 307,681, 267, 401
# chin dim (x_min, x_max, y_min, y_max): 427,550, 745, 848
# right cheek dim (x_min, x_max, y_min, y_max): 292,373, 506, 813
# left cheek dim (x_min, x_max, y_min, y_max): 550,703, 502, 813
# forehead dim (x_min, x_max, y_min, y_max): 296,651, 280, 406
# chin dim (x_min, x_max, y_min, y_max): 414,529, 728, 826
# right cheek dim (x_min, x_max, y_min, y_max): 284,362, 515, 794
# left cheek dim (x_min, x_max, y_min, y_max): 529,680, 503, 793
# forehead dim (x_min, x_max, y_min, y_max): 300,680, 239, 374
# chin dim (x_min, x_max, y_min, y_max): 424,550, 728, 825
# right cheek dim (x_min, x_max, y_min, y_max): 279,367, 480, 790
# left cheek dim (x_min, x_max, y_min, y_max): 550,702, 478, 789
# forehead dim (x_min, x_max, y_min, y_max): 294,657, 301, 434
# chin dim (x_min, x_max, y_min, y_max): 409,529, 775, 878
# right cheek dim (x_min, x_max, y_min, y_max): 278,358, 535, 843
# left cheek dim (x_min, x_max, y_min, y_max): 529,682, 532, 843
# forehead dim (x_min, x_max, y_min, y_max): 642,1747, 655, 1012
# chin dim (x_min, x_max, y_min, y_max): 1044,1375, 1990, 2203
# right cheek dim (x_min, x_max, y_min, y_max): 592,856, 1355, 2116
# left cheek dim (x_min, x_max, y_min, y_max): 1375,1774, 1332, 2114
# forehead dim (x_min, x_max, y_min, y_max): 620,1748, 737, 1118
# chin dim (x_min, x_max, y_min, y_max): 1007,1365, 2155, 2389
# right cheek dim (x_min, x_max, y_min, y_max): 569,821, 1474, 2295
# left cheek dim (x_min, x_max, y_min, y_max): 1365,1791, 1466, 2294
# forehead dim (x_min, x_max, y_min, y_max): 219,734, 266, 435
# chin dim (x_min, x_max, y_min, y_max): 393,559, 910, 1000
# right cheek dim (x_min, x_max, y_min, y_max): 201,310, 578, 956
# left cheek dim (x_min, x_max, y_min, y_max): 559,737, 579, 957
# forehead dim (x_min, x_max, y_min, y_max): 244,737, 273, 441
# chin dim (x_min, x_max, y_min, y_max): 418,580, 917, 1003
# right cheek dim (x_min, x_max, y_min, y_max): 199,340, 589, 960
# left cheek dim (x_min, x_max, y_min, y_max): 580,729, 599, 961
# forehead dim (x_min, x_max, y_min, y_max): 234,743, 280, 447
# chin dim (x_min, x_max, y_min, y_max): 406,568, 917, 1005
# right cheek dim (x_min, x_max, y_min, y_max): 212,325, 591, 962
# left cheek dim (x_min, x_max, y_min, y_max): 568,745, 588, 962
# forehead dim (x_min, x_max, y_min, y_max): 538,1375, 498, 803
# chin dim (x_min, x_max, y_min, y_max): 810,1076, 1575, 1822
# right cheek dim (x_min, x_max, y_min, y_max): 529,687, 1038, 1742
# left cheek dim (x_min, x_max, y_min, y_max): 1076,1424, 1045, 1743
# forehead dim (x_min, x_max, y_min, y_max): 548,1397, 627, 941
# chin dim (x_min, x_max, y_min, y_max): 830,1100, 1754, 1990
# right cheek dim (x_min, x_max, y_min, y_max): 524,700, 1198, 1909
# left cheek dim (x_min, x_max, y_min, y_max): 1100,1437, 1202, 1910
# forehead dim (x_min, x_max, y_min, y_max): 542,1422, 536, 874
# chin dim (x_min, x_max, y_min, y_max): 825,1107, 1732, 2001
# right cheek dim (x_min, x_max, y_min, y_max): 519,691, 1145, 1914
# left cheek dim (x_min, x_max, y_min, y_max): 1107,1482, 1156, 1915
# forehead dim (x_min, x_max, y_min, y_max): 216,723, 305, 468
# chin dim (x_min, x_max, y_min, y_max): 388,548, 901, 1014
# right cheek dim (x_min, x_max, y_min, y_max): 203,311, 589, 970
# left cheek dim (x_min, x_max, y_min, y_max): 548,750, 584, 970
# forehead dim (x_min, x_max, y_min, y_max): 269,725, 315, 464
# chin dim (x_min, x_max, y_min, y_max): 427,565, 859, 962
# right cheek dim (x_min, x_max, y_min, y_max): 254,352, 576, 922
# left cheek dim (x_min, x_max, y_min, y_max): 565,747, 582, 923
# forehead dim (x_min, x_max, y_min, y_max): 511,1437, 672, 971
# chin dim (x_min, x_max, y_min, y_max): 830,1101, 1809, 1969
# right cheek dim (x_min, x_max, y_min, y_max): 472,668, 1240, 1894
# left cheek dim (x_min, x_max, y_min, y_max): 1101,1468, 1255, 1896
# forehead dim (x_min, x_max, y_min, y_max): 495,1420, 635, 948
# chin dim (x_min, x_max, y_min, y_max): 815,1089, 1798, 1992
# right cheek dim (x_min, x_max, y_min, y_max): 465,663, 1209, 1912
# left cheek dim (x_min, x_max, y_min, y_max): 1089,1453, 1229, 1914
# forehead dim (x_min, x_max, y_min, y_max): 475,1498, 550, 887
# chin dim (x_min, x_max, y_min, y_max): 821,1126, 1824, 2012
# right cheek dim (x_min, x_max, y_min, y_max): 431,647, 1178, 1927
# left cheek dim (x_min, x_max, y_min, y_max): 1126,1520, 1203, 1929
# forehead dim (x_min, x_max, y_min, y_max): 481,1435, 633, 950
# chin dim (x_min, x_max, y_min, y_max): 810,1097, 1810, 2009
# right cheek dim (x_min, x_max, y_min, y_max): 450,645, 1208, 1927
# left cheek dim (x_min, x_max, y_min, y_max): 1097,1471, 1229, 1929
# forehead dim (x_min, x_max, y_min, y_max): 483,1433, 588, 915
# chin dim (x_min, x_max, y_min, y_max): 818,1094, 1794, 2007
# right cheek dim (x_min, x_max, y_min, y_max): 445,650, 1204, 1925
# left cheek dim (x_min, x_max, y_min, y_max): 1094,1477, 1223, 1927
# forehead dim (x_min, x_max, y_min, y_max): 264,701, 322, 477
# chin dim (x_min, x_max, y_min, y_max): 419,551, 898, 994
# right cheek dim (x_min, x_max, y_min, y_max): 241,346, 603, 954
# left cheek dim (x_min, x_max, y_min, y_max): 551,730, 599, 953
# forehead dim (x_min, x_max, y_min, y_max): 265,724, 275, 446
# chin dim (x_min, x_max, y_min, y_max): 428,565, 907, 1017
# right cheek dim (x_min, x_max, y_min, y_max): 237,353, 587, 973
# left cheek dim (x_min, x_max, y_min, y_max): 565,765, 581, 972
# forehead dim (x_min, x_max, y_min, y_max): 240,679, 261, 427
# chin dim (x_min, x_max, y_min, y_max): 396,531, 876, 982
# right cheek dim (x_min, x_max, y_min, y_max): 218,326, 571, 940
# left cheek dim (x_min, x_max, y_min, y_max): 531,697, 565, 939
# forehead dim (x_min, x_max, y_min, y_max): 289,676, 402, 533
# chin dim (x_min, x_max, y_min, y_max): 417,542, 856, 971
# right cheek dim (x_min, x_max, y_min, y_max): 274,357, 635, 936
# left cheek dim (x_min, x_max, y_min, y_max): 542,699, 634, 936
# forehead dim (x_min, x_max, y_min, y_max): 274,685, 382, 511
# chin dim (x_min, x_max, y_min, y_max): 415,543, 839, 942
# right cheek dim (x_min, x_max, y_min, y_max): 266,348, 602, 907
# left cheek dim (x_min, x_max, y_min, y_max): 543,705, 606, 907
# forehead dim (x_min, x_max, y_min, y_max): 287,701, 389, 518
# chin dim (x_min, x_max, y_min, y_max): 432,559, 843, 949
# right cheek dim (x_min, x_max, y_min, y_max): 278,367, 613, 914
# left cheek dim (x_min, x_max, y_min, y_max): 559,714, 616, 915
# forehead dim (x_min, x_max, y_min, y_max): 212,734, 235, 416
# chin dim (x_min, x_max, y_min, y_max): 381,544, 910, 1021
# right cheek dim (x_min, x_max, y_min, y_max): 213,293, 581, 976
# left cheek dim (x_min, x_max, y_min, y_max): 544,761, 576, 975
# forehead dim (x_min, x_max, y_min, y_max): 238,693, 292, 462
# chin dim (x_min, x_max, y_min, y_max): 393,544, 896, 1030
# right cheek dim (x_min, x_max, y_min, y_max): 223,330, 586, 985
# left cheek dim (x_min, x_max, y_min, y_max): 544,707, 579, 984
# forehead dim (x_min, x_max, y_min, y_max): 265,659, 333, 488
# chin dim (x_min, x_max, y_min, y_max): 403,533, 881, 1007
# right cheek dim (x_min, x_max, y_min, y_max): 247,347, 589, 964
# left cheek dim (x_min, x_max, y_min, y_max): 533,674, 587, 964
# forehead dim (x_min, x_max, y_min, y_max): 255,648, 337, 490
# chin dim (x_min, x_max, y_min, y_max): 387,522, 878, 1003
# right cheek dim (x_min, x_max, y_min, y_max): 235,333, 587, 961
# left cheek dim (x_min, x_max, y_min, y_max): 522,659, 582, 960
# forehead dim (x_min, x_max, y_min, y_max): 260,680, 335, 492
# chin dim (x_min, x_max, y_min, y_max): 399,543, 894, 1016
# right cheek dim (x_min, x_max, y_min, y_max): 245,344, 589, 972
# left cheek dim (x_min, x_max, y_min, y_max): 543,690, 586, 972
# forehead dim (x_min, x_max, y_min, y_max): 597,1336, 732, 996
# chin dim (x_min, x_max, y_min, y_max): 843,1085, 1718, 1879
# right cheek dim (x_min, x_max, y_min, y_max): 568,719, 1221, 1811
# left cheek dim (x_min, x_max, y_min, y_max): 1085,1364, 1220, 1811
# forehead dim (x_min, x_max, y_min, y_max): 564,1263, 772, 1009
# chin dim (x_min, x_max, y_min, y_max): 815,1017, 1675, 1800
# right cheek dim (x_min, x_max, y_min, y_max): 540,693, 1198, 1738
# left cheek dim (x_min, x_max, y_min, y_max): 1017,1278, 1207, 1739
# forehead dim (x_min, x_max, y_min, y_max): 449,1436, 679, 979
# chin dim (x_min, x_max, y_min, y_max): 809,1098, 1784, 1982
# right cheek dim (x_min, x_max, y_min, y_max): 403,657, 1222, 1904
# left cheek dim (x_min, x_max, y_min, y_max): 1098,1479, 1199, 1902
# forehead dim (x_min, x_max, y_min, y_max): 457,1437, 654, 963
# chin dim (x_min, x_max, y_min, y_max): 815,1105, 1778, 1994
# right cheek dim (x_min, x_max, y_min, y_max): 406,662, 1210, 1914
# left cheek dim (x_min, x_max, y_min, y_max): 1105,1481, 1185, 1911
# forehead dim (x_min, x_max, y_min, y_max): 489,1479, 654, 960
# chin dim (x_min, x_max, y_min, y_max): 848,1137, 1767, 1981
# right cheek dim (x_min, x_max, y_min, y_max): 445,697, 1192, 1900
# left cheek dim (x_min, x_max, y_min, y_max): 1137,1508, 1192, 1900
# forehead dim (x_min, x_max, y_min, y_max): 519,1512, 724, 1022
# chin dim (x_min, x_max, y_min, y_max): 869,1166, 1831, 2017
# right cheek dim (x_min, x_max, y_min, y_max): 461,716, 1269, 1940
# left cheek dim (x_min, x_max, y_min, y_max): 1166,1557, 1252, 1939
# forehead dim (x_min, x_max, y_min, y_max): 483,1458, 737, 1028
# chin dim (x_min, x_max, y_min, y_max): 834,1122, 1819, 1998
# right cheek dim (x_min, x_max, y_min, y_max): 417,685, 1274, 1924
# left cheek dim (x_min, x_max, y_min, y_max): 1122,1502, 1247, 1921
# forehead dim (x_min, x_max, y_min, y_max): 501,1357, 681, 972
# chin dim (x_min, x_max, y_min, y_max): 797,1052, 1730, 1943
# right cheek dim (x_min, x_max, y_min, y_max): 483,656, 1223, 1869
# left cheek dim (x_min, x_max, y_min, y_max): 1052,1410, 1215, 1868
# forehead dim (x_min, x_max, y_min, y_max): 488,1416, 471, 801
# chin dim (x_min, x_max, y_min, y_max): 792,1085, 1662, 1901
# right cheek dim (x_min, x_max, y_min, y_max): 458,648, 1078, 1817
# left cheek dim (x_min, x_max, y_min, y_max): 1085,1473, 1083, 1818
# forehead dim (x_min, x_max, y_min, y_max): 252,704, 243, 429
# chin dim (x_min, x_max, y_min, y_max): 398,559, 919, 1049
# right cheek dim (x_min, x_max, y_min, y_max): 217,330, 572, 1000
# left cheek dim (x_min, x_max, y_min, y_max): 559,739, 567, 1000
# forehead dim (x_min, x_max, y_min, y_max): 204,717, 182, 379
# chin dim (x_min, x_max, y_min, y_max): 381,550, 899, 1038
# right cheek dim (x_min, x_max, y_min, y_max): 150,298, 541, 987
# left cheek dim (x_min, x_max, y_min, y_max): 550,747, 532, 986
# forehead dim (x_min, x_max, y_min, y_max): 234,703, 270, 458
# chin dim (x_min, x_max, y_min, y_max): 384,544, 953, 1085
# right cheek dim (x_min, x_max, y_min, y_max): 203,311, 608, 1036
# left cheek dim (x_min, x_max, y_min, y_max): 544,740, 602, 1036
# forehead dim (x_min, x_max, y_min, y_max): 273,648, 273, 422
# chin dim (x_min, x_max, y_min, y_max): 395,524, 812, 921
# right cheek dim (x_min, x_max, y_min, y_max): 252,333, 543, 882
# left cheek dim (x_min, x_max, y_min, y_max): 524,677, 536, 882
# forehead dim (x_min, x_max, y_min, y_max): 624,1650, 748, 1119
# chin dim (x_min, x_max, y_min, y_max): 988,1310, 2154, 2357
# right cheek dim (x_min, x_max, y_min, y_max): 591,807, 1464, 2266
# left cheek dim (x_min, x_max, y_min, y_max): 1310,1690, 1438, 2263
# forehead dim (x_min, x_max, y_min, y_max): 640,1634, 707, 1080
# chin dim (x_min, x_max, y_min, y_max): 981,1317, 2118, 2325
# right cheek dim (x_min, x_max, y_min, y_max): 603,813, 1425, 2233
# left cheek dim (x_min, x_max, y_min, y_max): 1317,1671, 1408, 2231
# forehead dim (x_min, x_max, y_min, y_max): 552,1666, 643, 1066
# chin dim (x_min, x_max, y_min, y_max): 939,1301, 2241, 2479
# right cheek dim (x_min, x_max, y_min, y_max): 525,741, 1468, 2375
# left cheek dim (x_min, x_max, y_min, y_max): 1301,1722, 1422, 2371
# forehead dim (x_min, x_max, y_min, y_max): 712,1599, 767, 1102
# chin dim (x_min, x_max, y_min, y_max): 1018,1308, 2029, 2220
# right cheek dim (x_min, x_max, y_min, y_max): 663,857, 1401, 2136
# left cheek dim (x_min, x_max, y_min, y_max): 1308,1637, 1384, 2134
# forehead dim (x_min, x_max, y_min, y_max): 580,1621, 684, 1067
# chin dim (x_min, x_max, y_min, y_max): 947,1288, 2141, 2344
# right cheek dim (x_min, x_max, y_min, y_max): 558,759, 1414, 2249
# left cheek dim (x_min, x_max, y_min, y_max): 1288,1728, 1393, 2247
# forehead dim (x_min, x_max, y_min, y_max): 500,1459, 520, 884
# chin dim (x_min, x_max, y_min, y_max): 812,1129, 1854, 2098
# right cheek dim (x_min, x_max, y_min, y_max): 448,648, 1209, 2007
# left cheek dim (x_min, x_max, y_min, y_max): 1129,1503, 1222, 2008
# forehead dim (x_min, x_max, y_min, y_max): 491,1418, 488, 855
# chin dim (x_min, x_max, y_min, y_max): 798,1101, 1760, 2080
# right cheek dim (x_min, x_max, y_min, y_max): 459,642, 1153, 1985
# left cheek dim (x_min, x_max, y_min, y_max): 1101,1468, 1173, 1987
# forehead dim (x_min, x_max, y_min, y_max): 492,1462, 537, 883
# chin dim (x_min, x_max, y_min, y_max): 811,1125, 1792, 2037
# right cheek dim (x_min, x_max, y_min, y_max): 444,652, 1150, 1946
# left cheek dim (x_min, x_max, y_min, y_max): 1125,1505, 1153, 1947
# forehead dim (x_min, x_max, y_min, y_max): 662,1640, 762, 1162
# chin dim (x_min, x_max, y_min, y_max): 977,1310, 2223, 2496
# right cheek dim (x_min, x_max, y_min, y_max): 629,812, 1485, 2392
# left cheek dim (x_min, x_max, y_min, y_max): 1310,1691, 1495, 2394
# forehead dim (x_min, x_max, y_min, y_max): 626,1584, 749, 1135
# chin dim (x_min, x_max, y_min, y_max): 943,1267, 2154, 2423
# right cheek dim (x_min, x_max, y_min, y_max): 556,781, 1447, 2323
# left cheek dim (x_min, x_max, y_min, y_max): 1267,1645, 1454, 2324
# forehead dim (x_min, x_max, y_min, y_max): 661,1625, 796, 1159
# chin dim (x_min, x_max, y_min, y_max): 985,1290, 2126, 2370
# right cheek dim (x_min, x_max, y_min, y_max): 575,829, 1454, 2276
# left cheek dim (x_min, x_max, y_min, y_max): 1290,1683, 1456, 2276
# forehead dim (x_min, x_max, y_min, y_max): 676,1517, 880, 1189
# chin dim (x_min, x_max, y_min, y_max): 972,1216, 1988, 2220
# right cheek dim (x_min, x_max, y_min, y_max): 644,826, 1469, 2143
# left cheek dim (x_min, x_max, y_min, y_max): 1216,1551, 1476, 2144
# forehead dim (x_min, x_max, y_min, y_max): 706,1558, 884, 1173
# chin dim (x_min, x_max, y_min, y_max): 1018,1265, 1909, 2138
# right cheek dim (x_min, x_max, y_min, y_max): 668,873, 1416, 2064
# left cheek dim (x_min, x_max, y_min, y_max): 1265,1604, 1415, 2064
# Face not detected by landmarks model...
# [1021 1013  285  285]
# Right eye detected
# forehead dim (x_min, x_max, y_min, y_max): 593,1448, 585, 870
# cheek dim (x_min, x_max, y_min, y_max): 223,1163, 1298, 2295
# forehead dim (x_min, x_max, y_min, y_max): 549,1338, 680, 958
# chin dim (x_min, x_max, y_min, y_max): 839,1061, 1676, 1886
# right cheek dim (x_min, x_max, y_min, y_max): 522,707, 1206, 1816
# left cheek dim (x_min, x_max, y_min, y_max): 1061,1357, 1194, 1815
# forehead dim (x_min, x_max, y_min, y_max): 542,1325, 651, 929
# chin dim (x_min, x_max, y_min, y_max): 832,1056, 1645, 1857
# right cheek dim (x_min, x_max, y_min, y_max): 504,701, 1174, 1787
# left cheek dim (x_min, x_max, y_min, y_max): 1056,1334, 1162, 1786
# forehead dim (x_min, x_max, y_min, y_max): 241,710, 330, 492
# chin dim (x_min, x_max, y_min, y_max): 407,550, 950, 1034
# right cheek dim (x_min, x_max, y_min, y_max): 224,333, 611, 991
# left cheek dim (x_min, x_max, y_min, y_max): 550,721, 609, 991
# forehead dim (x_min, x_max, y_min, y_max): 253,706, 363, 519
# chin dim (x_min, x_max, y_min, y_max): 417,550, 957, 1040
# right cheek dim (x_min, x_max, y_min, y_max): 241,340, 639, 999
# left cheek dim (x_min, x_max, y_min, y_max): 550,721, 634, 998
# forehead dim (x_min, x_max, y_min, y_max): 570,1374, 644, 954
# chin dim (x_min, x_max, y_min, y_max): 832,1095, 1799, 1990
# right cheek dim (x_min, x_max, y_min, y_max): 528,694, 1221, 1911
# left cheek dim (x_min, x_max, y_min, y_max): 1095,1411, 1231, 1912
# forehead dim (x_min, x_max, y_min, y_max): 557,1401, 657, 952
# chin dim (x_min, x_max, y_min, y_max): 839,1114, 1766, 1937
# right cheek dim (x_min, x_max, y_min, y_max): 528,698, 1195, 1861
# left cheek dim (x_min, x_max, y_min, y_max): 1114,1432, 1207, 1862
# forehead dim (x_min, x_max, y_min, y_max): 624,1351, 692, 962
# chin dim (x_min, x_max, y_min, y_max): 868,1097, 1705, 1864
# right cheek dim (x_min, x_max, y_min, y_max): 588,742, 1199, 1796
# left cheek dim (x_min, x_max, y_min, y_max): 1097,1387, 1207, 1797
# forehead dim (x_min, x_max, y_min, y_max): 450,1485, 619, 952
# chin dim (x_min, x_max, y_min, y_max): 806,1114, 1860, 2063
# right cheek dim (x_min, x_max, y_min, y_max): 443,643, 1191, 1974
# left cheek dim (x_min, x_max, y_min, y_max): 1114,1498, 1198, 1975
# forehead dim (x_min, x_max, y_min, y_max): 501,1429, 646, 966
# chin dim (x_min, x_max, y_min, y_max): 815,1098, 1821, 2033
# right cheek dim (x_min, x_max, y_min, y_max): 479,667, 1208, 1949
# left cheek dim (x_min, x_max, y_min, y_max): 1098,1456, 1204, 1948
# forehead dim (x_min, x_max, y_min, y_max): 491,1443, 671, 981
# chin dim (x_min, x_max, y_min, y_max): 823,1113, 1826, 2015
# right cheek dim (x_min, x_max, y_min, y_max): 481,677, 1201, 1932
# left cheek dim (x_min, x_max, y_min, y_max): 1113,1455, 1203, 1932
# forehead dim (x_min, x_max, y_min, y_max): 519,1420, 677, 990
# chin dim (x_min, x_max, y_min, y_max): 832,1110, 1833, 2034
# right cheek dim (x_min, x_max, y_min, y_max): 515,692, 1245, 1953
# left cheek dim (x_min, x_max, y_min, y_max): 1110,1469, 1221, 1951
# forehead dim (x_min, x_max, y_min, y_max): 440,1474, 584, 941
# chin dim (x_min, x_max, y_min, y_max): 799,1112, 1893, 2132
# right cheek dim (x_min, x_max, y_min, y_max): 426,632, 1211, 2038
# left cheek dim (x_min, x_max, y_min, y_max): 1112,1564, 1200, 2037
# forehead dim (x_min, x_max, y_min, y_max): 320,708, 452, 579
# chin dim (x_min, x_max, y_min, y_max): 454,572, 904, 1004
# right cheek dim (x_min, x_max, y_min, y_max): 300,392, 658, 968
# left cheek dim (x_min, x_max, y_min, y_max): 572,714, 663, 969
# forehead dim (x_min, x_max, y_min, y_max): 314,708, 401, 522
# chin dim (x_min, x_max, y_min, y_max): 450,572, 839, 928
# right cheek dim (x_min, x_max, y_min, y_max): 303,390, 606, 895
# left cheek dim (x_min, x_max, y_min, y_max): 572,720, 603, 895
# forehead dim (x_min, x_max, y_min, y_max): 532,1355, 609, 930
# chin dim (x_min, x_max, y_min, y_max): 822,1078, 1751, 2003
# right cheek dim (x_min, x_max, y_min, y_max): 511,691, 1190, 1920
# left cheek dim (x_min, x_max, y_min, y_max): 1078,1379, 1190, 1920
# forehead dim (x_min, x_max, y_min, y_max): 518,1372, 608, 935
# chin dim (x_min, x_max, y_min, y_max): 819,1082, 1782, 2027
# right cheek dim (x_min, x_max, y_min, y_max): 475,686, 1189, 1942
# left cheek dim (x_min, x_max, y_min, y_max): 1082,1407, 1190, 1942
# forehead dim (x_min, x_max, y_min, y_max): 562,1367, 608, 928
# chin dim (x_min, x_max, y_min, y_max): 848,1096, 1737, 1996
# right cheek dim (x_min, x_max, y_min, y_max): 519,718, 1209, 1916
# left cheek dim (x_min, x_max, y_min, y_max): 1096,1396, 1208, 1916
# forehead dim (x_min, x_max, y_min, y_max): 581,1572, 627, 1028
# chin dim (x_min, x_max, y_min, y_max): 916,1236, 2015, 2365
# right cheek dim (x_min, x_max, y_min, y_max): 561,750, 1343, 2260
# left cheek dim (x_min, x_max, y_min, y_max): 1236,1637, 1319, 2258
# forehead dim (x_min, x_max, y_min, y_max): 579,1715, 412, 871
# chin dim (x_min, x_max, y_min, y_max): 948,1336, 1984, 2401
# right cheek dim (x_min, x_max, y_min, y_max): 528,773, 1229, 2281
# left cheek dim (x_min, x_max, y_min, y_max): 1336,1784, 1197, 2278
# forehead dim (x_min, x_max, y_min, y_max): 538,1620, 527, 955
# chin dim (x_min, x_max, y_min, y_max): 901,1261, 1970, 2382
# right cheek dim (x_min, x_max, y_min, y_max): 497,723, 1268, 2268
# left cheek dim (x_min, x_max, y_min, y_max): 1261,1672, 1262, 2268
# Face not detected by landmarks model...
# [  799.   1858.    289.8   289.8]
# Right eye detected
# forehead dim (x_min, x_max, y_min, y_max): 364,1233, 1423, 1713
# cheek dim (x_min, x_max, y_min, y_max): 0,943, 2147, 2576
# forehead dim (x_min, x_max, y_min, y_max): 509,1445, 443, 820
# chin dim (x_min, x_max, y_min, y_max): 831,1127, 1713, 2077
# right cheek dim (x_min, x_max, y_min, y_max): 474,680, 1114, 1979
# left cheek dim (x_min, x_max, y_min, y_max): 1127,1495, 1094, 1977
# forehead dim (x_min, x_max, y_min, y_max): 466,1402, 543, 879
# chin dim (x_min, x_max, y_min, y_max): 793,1083, 1718, 2001
# right cheek dim (x_min, x_max, y_min, y_max): 419,658, 1141, 1914
# left cheek dim (x_min, x_max, y_min, y_max): 1083,1442, 1137, 1913
# forehead dim (x_min, x_max, y_min, y_max): 515,1419, 657, 973
# chin dim (x_min, x_max, y_min, y_max): 823,1110, 1799, 2027
# right cheek dim (x_min, x_max, y_min, y_max): 478,691, 1230, 1946
# left cheek dim (x_min, x_max, y_min, y_max): 1110,1457, 1215, 1944
# forehead dim (x_min, x_max, y_min, y_max): 611,1315, 543, 811
# chin dim (x_min, x_max, y_min, y_max): 844,1077, 1477, 1705
# right cheek dim (x_min, x_max, y_min, y_max): 550,732, 1039, 1637
# left cheek dim (x_min, x_max, y_min, y_max): 1077,1365, 1036, 1637
# forehead dim (x_min, x_max, y_min, y_max): 540,1436, 555, 870
# chin dim (x_min, x_max, y_min, y_max): 840,1130, 1756, 1923
# right cheek dim (x_min, x_max, y_min, y_max): 506,686, 1132, 1842
# left cheek dim (x_min, x_max, y_min, y_max): 1130,1444, 1132, 1842
# forehead dim (x_min, x_max, y_min, y_max): 509,1402, 592, 900
# chin dim (x_min, x_max, y_min, y_max): 810,1097, 1730, 1929
# right cheek dim (x_min, x_max, y_min, y_max): 482,662, 1154, 1850
# left cheek dim (x_min, x_max, y_min, y_max): 1097,1415, 1154, 1850
# forehead dim (x_min, x_max, y_min, y_max): 269,680, 370, 509
# chin dim (x_min, x_max, y_min, y_max): 407,536, 886, 975
# right cheek dim (x_min, x_max, y_min, y_max): 258,345, 620, 938
# left cheek dim (x_min, x_max, y_min, y_max): 536,711, 610, 937
# forehead dim (x_min, x_max, y_min, y_max): 697,1556, 848, 1149
# chin dim (x_min, x_max, y_min, y_max): 997,1255, 1903, 2154
# right cheek dim (x_min, x_max, y_min, y_max): 652,861, 1370, 2074
# left cheek dim (x_min, x_max, y_min, y_max): 1255,1574, 1357, 2073
# forehead dim (x_min, x_max, y_min, y_max): 723,1632, 593, 933
# chin dim (x_min, x_max, y_min, y_max): 1013,1311, 1787, 2067
# right cheek dim (x_min, x_max, y_min, y_max): 686,873, 1244, 1983
# left cheek dim (x_min, x_max, y_min, y_max): 1311,1705, 1242, 1983
# forehead dim (x_min, x_max, y_min, y_max): 631,1722, 663, 1082
# chin dim (x_min, x_max, y_min, y_max): 977,1357, 2221, 2481
# right cheek dim (x_min, x_max, y_min, y_max): 595,799, 1453, 2376
# left cheek dim (x_min, x_max, y_min, y_max): 1357,1761, 1451, 2376
# forehead dim (x_min, x_max, y_min, y_max): 543,1688, 592, 1025
# chin dim (x_min, x_max, y_min, y_max): 908,1306, 2189, 2471
# right cheek dim (x_min, x_max, y_min, y_max): 538,718, 1392, 2361
# left cheek dim (x_min, x_max, y_min, y_max): 1306,1752, 1374, 2360
# forehead dim (x_min, x_max, y_min, y_max): 612,1730, 669, 1072
# chin dim (x_min, x_max, y_min, y_max): 975,1349, 2144, 2418
# right cheek dim (x_min, x_max, y_min, y_max): 612,803, 1410, 2316
# left cheek dim (x_min, x_max, y_min, y_max): 1349,1759, 1402, 2315
# forehead dim (x_min, x_max, y_min, y_max): 587,1723, 652, 1076
# chin dim (x_min, x_max, y_min, y_max): 948,1320, 2222, 2491
# right cheek dim (x_min, x_max, y_min, y_max): 554,760, 1436, 2384
# left cheek dim (x_min, x_max, y_min, y_max): 1320,1745, 1436, 2384
# forehead dim (x_min, x_max, y_min, y_max): 189,771, 192, 389
# chin dim (x_min, x_max, y_min, y_max): 380,583, 964, 1048
# right cheek dim (x_min, x_max, y_min, y_max): 190,282, 586, 1001
# left cheek dim (x_min, x_max, y_min, y_max): 583,776, 583, 1000
# forehead dim (x_min, x_max, y_min, y_max): 556,1688, 400, 866
# chin dim (x_min, x_max, y_min, y_max): 949,1293, 2064, 2421
# right cheek dim (x_min, x_max, y_min, y_max): 499,761, 1262, 2303
# left cheek dim (x_min, x_max, y_min, y_max): 1293,1737, 1271, 2304
# forehead dim (x_min, x_max, y_min, y_max): 409,1711, 326, 883
# chin dim (x_min, x_max, y_min, y_max): 881,1271, 2281, 2741
# right cheek dim (x_min, x_max, y_min, y_max): 272,680, 1362, 2601
# left cheek dim (x_min, x_max, y_min, y_max): 1271,1824, 1326, 2598

# %% [markdown]
# ## Predict Image Patch Label

# %% [markdown]
# ### Load CNTK Pretrained Model

# %%
# define pretrained model location, node name
model_file  = os.path.join(pretrained_model_path, pretrained_model_name)
loaded_model  = load_model(model_file)
node_in_graph = loaded_model.find_by_name(pretrained_node_name)
output_nodes  = combine([node_in_graph.owner])

node_outputs = C.logging.get_node_outputs(loaded_model)
for l in node_outputs: 
    if l.name == pretrained_node_name:
        num_nodes = np.prod(np.array(l.shape))
        
print ('the pretrained model is %s' % pretrained_model_name)
print ('the selected layer name is %s and the number of flatten nodes is %d' % (pretrained_node_name, num_nodes))
# Out:
# the pretrained model is ResNet152_ImageNet_Caffe.model
# the selected layer name is pool5 and the number of flatten nodes is 2048

# %%
def extract_features(image_path):   
    img = Image.open(image_path)       
    resized = img.resize((image_width, image_height), Image.ANTIALIAS)  
    
    bgr_image = np.asarray(resized, dtype=np.float32)[..., [2, 1, 0]]    
    hwc_format = np.ascontiguousarray(np.rollaxis(bgr_image, 2)) 
    
    arguments = {loaded_model.arguments[0]: [hwc_format]}    
    output = output_nodes.eval(arguments)   
    return output

# %% [markdown]
# ### Load NN model

# %%
#load the stored regression model
read_model = pd.read_pickle(regression_model_path)
regression_model = read_model['model'][0]
train_regression = pickle.loads(regression_model)

# %% [markdown]
# ### Score Image

# %%
# get the score value for each patch
patch_score = dict()
for file in next(os.walk(patch_path))[2]:
    file_path = os.path.join(patch_path, file)
    # extract features from CNTK pretrained model
    score_features = extract_features (file_path)[0].flatten()
    # score the extracted features using trained regression model
    pred_score_label = train_regression.predict(score_features.reshape(1,-1))
    patch_score[file] = float("{0:.2f}".format(pred_score_label[0]))

# %% [markdown]
# ### Check the predicted labels of skin patches

# %%
patch_score
# Out:
# {'0006_chin.jpg': 2.91,
#  '0006_fh.jpg': 3.49,
#  '0006_lc.jpg': 4.14,
#  '0006_rc.jpg': 2.0,
#  '0007_chin.jpg': 2.5,
#  '0007_fh.jpg': 3.41,
#  '0007_lc.jpg': 2.77,
#  '0007_rc.jpg': 2.96,
#  '0010_chin.jpg': 2.24,
#  '0010_fh.jpg': 2.43,
#  '0010_lc.jpg': 2.68,
#  '0010_rc.jpg': 2.74,
#  '0025_chin.jpg': 3.24,
#  '0025_fh.jpg': 2.45,
#  '0025_rc.jpg': 3.22,
#  '0030_chin.jpg': 2.52,
#  '0030_fh.jpg': 2.73,
#  '0030_lc.jpg': 2.33,
#  '0030_rc.jpg': 3.13,
#  '0050_chin.jpg': 1.79,
#  '0050_fh.jpg': 3.95,
#  '0050_rc.jpg': 3.83,
#  '0078_chin.jpg': 2.18,
#  '0078_fh.jpg': 1.78,
#  '0078_lc.jpg': 3.61,
#  '0078_rc.jpg': 2.58,
#  '0079_chin.jpg': 2.74,
#  '0079_fh.jpg': 2.01,
#  '0079_lc.jpg': 2.85,
#  '0079_rc.jpg': 2.44,
#  '0090_chin.jpg': 2.88,
#  '0090_fh.jpg': 2.67,
#  '0090_lc.jpg': 3.34,
#  '0090_rc.jpg': 2.86,
#  '0091_chin.jpg': 2.32,
#  '0091_fh.jpg': 3.34,
#  '0091_lc.jpg': 3.48,
#  '0091_rc.jpg': 2.99,
#  '0097_chin.jpg': 3.16,
#  '0097_fh.jpg': 3.69,
#  '0097_lc.jpg': 2.67,
#  '0097_rc.jpg': 3.29,
#  '0108_chin.jpg': 2.23,
#  '0108_fh.jpg': 4.56,
#  '0108_lc.jpg': 3.99,
#  '0108_rc.jpg': 2.75,
#  '0109_chin.jpg': 3.45,
#  '0109_fh.jpg': 2.14,
#  '0109_lc.jpg': 2.93,
#  '0109_rc.jpg': 2.88,
#  '0112_chin.jpg': 1.95,
#  '0112_fh.jpg': 3.98,
#  '0112_lc.jpg': 2.72,
#  '0112_rc.jpg': 3.36,
#  '0116_chin.jpg': 3.08,
#  '0116_fh.jpg': 4.27,
#  '0116_lc.jpg': 2.7,
#  '2158_fh.jpg': 3.14,
#  '2158_lc.jpg': 3.41,
#  '2158_rc.jpg': 3.12,
#  '2164_chin.jpg': 2.74,
#  '2164_fh.jpg': 3.56,
#  '2164_lc.jpg': 3.82,
#  '2164_rc.jpg': 3.61,
#  '2170_chin.jpg': 3.47,
#  '2170_fh.jpg': 3.36,
#  '2170_lc.jpg': 3.58,
#  '2170_rc.jpg': 2.99,
#  '2173_chin.jpg': 2.25,
#  '2173_fh.jpg': 3.76,
#  '2173_lc.jpg': 4.33,
#  '2173_rc.jpg': 3.98,
#  '2178_chin.jpg': 2.99,
#  '2178_fh.jpg': 3.07,
#  '2178_lc.jpg': 2.15,
#  '2178_rc.jpg': 3.4,
#  '2182_chin.jpg': 3.27,
#  '2182_fh.jpg': 2.75,
#  '2182_lc.jpg': 3.65,
#  '2182_rc.jpg': 3.62,
#  '2190_chin.jpg': 3.58,
#  '2190_fh.jpg': 3.02,
#  '2190_lc.jpg': 2.61,
#  '2190_rc.jpg': 3.09,
#  '2220_chin.jpg': 3.34,
#  '2220_fh.jpg': 2.72,
#  '2220_lc.jpg': 2.5,
#  '2220_rc.jpg': 2.25,
#  '2236_chin.jpg': 3.11,
#  '2236_fh.jpg': 2.78,
#  '2236_lc.jpg': 3.01,
#  '2236_rc.jpg': 3.68,
#  '2252_chin.jpg': 3.46,
#  '2252_fh.jpg': 3.21,
#  '2252_lc.jpg': 2.68,
#  '2252_rc.jpg': 3.48,
#  '2270_chin.jpg': 3.31,
#  '2270_fh.jpg': 3.6,
#  '2270_lc.jpg': 2.85,
#  '2270_rc.jpg': 3.1,
#  '2281_chin.jpg': 3.15,
#  '2281_fh.jpg': 3.71,
#  '2281_lc.jpg': 2.87,
#  '2281_rc.jpg': 2.06,
#  '2296_chin.jpg': 2.63,
#  '2296_fh.jpg': 2.62,
#  '2296_lc.jpg': 3.43,
#  '2296_rc.jpg': 3.35,
#  '2302_chin.jpg': 3.03,
#  '2302_fh.jpg': 2.59,
#  '2302_lc.jpg': 3.03,
#  '2302_rc.jpg': 3.59,
#  '2309_fh.jpg': 2.21,
#  '2309_rc.jpg': 3.39,
#  '2328_chin.jpg': 2.75,
#  '2328_fh.jpg': 2.42,
#  '2328_lc.jpg': 2.96,
#  '2328_rc.jpg': 2.8,
#  '2402_chin.jpg': 2.86,
#  '2402_fh.jpg': 4.76,
#  '2402_lc.jpg': 3.25,
#  '2402_rc.jpg': 3.1,
#  '2407_chin.jpg': 2.44,
#  '2407_fh.jpg': 2.45,
#  '2407_lc.jpg': 3.69,
#  '2407_rc.jpg': 3.32,
#  '2418_chin.jpg': 2.42,
#  '2418_fh.jpg': 3.38,
#  '2418_lc.jpg': 3.59,
#  '2418_rc.jpg': 4.6,
#  '2428_chin.jpg': 2.66,
#  '2428_fh.jpg': 2.6,
#  '2428_lc.jpg': 2.02,
#  '2428_rc.jpg': 2.18,
#  '2443_chin.jpg': 3.49,
#  '2443_fh.jpg': 2.63,
#  '2443_lc.jpg': 3.98,
#  '2443_rc.jpg': 3.48,
#  '2494_chin.jpg': 2.25,
#  '2494_fh.jpg': 3.69,
#  '2494_lc.jpg': 3.24,
#  '2494_rc.jpg': 3.42,
#  '2506_chin.jpg': 4.32,
#  '2506_fh.jpg': 3.88,
#  '2506_lc.jpg': 4.34,
#  '2506_rc.jpg': 3.5,
#  '2558_chin.jpg': 4.88,
#  '2558_fh.jpg': 4.95,
#  '2558_lc.jpg': 4.58,
#  '2558_rc.jpg': 4.1,
#  '2607_chin.jpg': 4.17,
#  '2607_fh.jpg': 4.74,
#  '2607_lc.jpg': 3.6,
#  '2607_rc.jpg': 5.03,
#  '2620_chin.jpg': 1.9,
#  '2620_fh.jpg': 2.94,
#  '2620_lc.jpg': 2.63,
#  '2620_rc.jpg': 2.49,
#  '2698_chin.jpg': 2.87,
#  '2698_fh.jpg': 2.69,
#  '2698_lc.jpg': 2.9,
#  '2698_rc.jpg': 2.31,
#  '2805_chin.jpg': 2.23,
#  '2805_fh.jpg': 2.15,
#  '2805_lc.jpg': 3.16,
#  '2805_rc.jpg': 2.3,
#  '2814_chin.jpg': 1.05,
#  '2814_fh.jpg': 1.62,
#  '2814_lc.jpg': 1.97,
#  '2814_rc.jpg': 1.64,
#  '2967_chin.jpg': 2.21,
#  '2967_fh.jpg': 2.15,
#  '2967_lc.jpg': 2.07,
#  '2967_rc.jpg': 3.06,
#  '3029_chin.jpg': 2.8,
#  '3029_fh.jpg': 2.2,
#  '3029_lc.jpg': 3.18,
#  '3029_rc.jpg': 3.01,
#  '3079_chin.jpg': 4.18,
#  '3079_fh.jpg': 4.4,
#  '3079_lc.jpg': 3.2,
#  '3079_rc.jpg': 3.64,
#  '3094_chin.jpg': 2.79,
#  '3094_fh.jpg': 2.99,
#  '3094_lc.jpg': 3.1,
#  '3094_rc.jpg': 2.84,
#  '3097_chin.jpg': 3.07,
#  '3097_fh.jpg': 2.21,
#  '3097_lc.jpg': 4.63,
#  '3097_rc.jpg': 3.28,
#  '3115_chin.jpg': 2.97,
#  '3115_fh.jpg': 3.37,
#  '3115_lc.jpg': 3.28,
#  '3115_rc.jpg': 2.54,
#  '3201_chin.jpg': 3.25,
#  '3201_fh.jpg': 2.61,
#  '3201_lc.jpg': 2.54,
#  '3201_rc.jpg': 2.57,
#  '3210_chin.jpg': 2.59,
#  '3210_fh.jpg': 3.08,
#  '3210_lc.jpg': 2.37,
#  '3210_rc.jpg': 3.63,
#  '3229_chin.jpg': 2.96,
#  '3229_fh.jpg': 2.2,
#  '3229_lc.jpg': 2.49,
#  '3229_rc.jpg': 2.73,
#  '3244_chin.jpg': 2.18,
#  '3244_fh.jpg': 1.45,
#  '3244_lc.jpg': 2.62,
#  '3244_rc.jpg': 2.84,
#  '3280_chin.jpg': 1.87,
#  '3280_fh.jpg': 3.36,
#  '3280_lc.jpg': 2.38,
#  '3280_rc.jpg': 2.05,
#  '3309_chin.jpg': 3.91,
#  '3309_fh.jpg': 2.15,
#  '3309_lc.jpg': 2.85,
#  '3309_rc.jpg': 3.64,
#  '3673_lc.jpg': 3.17,
#  '3673_rc.jpg': 3.71,
#  '3687_chin.jpg': 3.81,
#  '3687_fh.jpg': 3.7,
#  '3687_lc.jpg': 3.09,
#  '3687_rc.jpg': 3.49,
#  '3702_chin.jpg': 2.88,
#  '3702_fh.jpg': 3.02,
#  '3702_lc.jpg': 1.67,
#  '3702_rc.jpg': 2.25,
#  '3707_chin.jpg': 3.71,
#  '3707_fh.jpg': 2.96,
#  '3707_lc.jpg': 3.93,
#  '3707_rc.jpg': 2.7,
#  '3712_chin.jpg': 4.38,
#  '3712_fh.jpg': 3.53,
#  '3712_lc.jpg': 4.0,
#  '3712_rc.jpg': 3.46,
#  '3720_chin.jpg': 3.43,
#  '3720_fh.jpg': 3.1,
#  '3720_lc.jpg': 2.43,
#  '3720_rc.jpg': 3.53,
#  '3728_chin.jpg': 2.11,
#  '3728_fh.jpg': 3.29,
#  '3728_lc.jpg': 3.87,
#  '3728_rc.jpg': 3.07,
#  '3749_chin.jpg': 1.82,
#  '3749_fh.jpg': 3.11,
#  '3749_lc.jpg': 1.93,
#  '3749_rc.jpg': 2.39,
#  '3759_chin.jpg': 3.36,
#  '3759_fh.jpg': 1.93,
#  '3759_lc.jpg': 3.05,
#  '3759_rc.jpg': 2.42,
#  '3767_chin.jpg': 2.93,
#  '3767_fh.jpg': 3.54,
#  '3767_lc.jpg': 2.57,
#  '3767_rc.jpg': 2.18,
#  '3771_chin.jpg': 2.91,
#  '3771_fh.jpg': 3.23,
#  '3771_lc.jpg': 3.47,
#  '3771_rc.jpg': 2.93,
#  '3777_chin.jpg': 3.89,
#  '3777_fh.jpg': 3.33,
#  '3777_lc.jpg': 3.58,
#  '3777_rc.jpg': 3.12,
#  '3787_chin.jpg': 3.21,
#  '3787_fh.jpg': 3.79,
#  '3787_lc.jpg': 2.29,
#  '3787_rc.jpg': 2.84,
#  '3788_chin.jpg': 3.01,
#  '3788_fh.jpg': 3.36,
#  '3788_lc.jpg': 3.41,
#  '3788_rc.jpg': 2.65,
#  '3801_chin.jpg': 2.44,
#  '3801_fh.jpg': 3.26,
#  '3801_lc.jpg': 2.82,
#  '3801_rc.jpg': 2.34,
#  '3813_chin.jpg': 2.95,
#  '3813_fh.jpg': 2.84,
#  '3813_lc.jpg': 2.9,
#  '3813_rc.jpg': 3.38,
#  '3819_chin.jpg': 3.63,
#  '3819_fh.jpg': 2.37,
#  '3819_lc.jpg': 4.01,
#  '3819_rc.jpg': 2.9,
#  '3823_chin.jpg': 3.53,
#  '3823_fh.jpg': 3.15,
#  '3823_lc.jpg': 3.44,
#  '3823_rc.jpg': 2.68,
#  '3830_chin.jpg': 2.9,
#  '3830_fh.jpg': 2.12,
#  '3830_lc.jpg': 3.89,
#  '3830_rc.jpg': 2.78,
#  '3839_chin.jpg': 3.52,
#  '3839_fh.jpg': 2.41,
#  '3839_lc.jpg': 3.9,
#  '3839_rc.jpg': 2.96,
#  '3846_chin.jpg': 2.67,
#  '3846_fh.jpg': 2.78,
#  '4350_rc.jpg': 2.35,
#  '4368_chin.jpg': 2.28,
#  '4368_fh.jpg': 3.04,
#  '4368_lc.jpg': 2.21,
#  '4368_rc.jpg': 3.23,
#  '4390_chin.jpg': 3.25,
#  '4390_fh.jpg': 2.52,
#  '4390_lc.jpg': 2.64,
#  '4390_rc.jpg': 2.64,
#  '4456_chin.jpg': 1.7,
#  '4456_fh.jpg': 2.88,
#  '4456_lc.jpg': 2.25,
#  '4456_rc.jpg': 2.74,
#  '4468_chin.jpg': 2.49,
#  '4468_fh.jpg': 2.28,
#  '4468_lc.jpg': 2.69,
#  '4468_rc.jpg': 2.53,
#  '4474_chin.jpg': 2.59,
#  '4474_fh.jpg': 2.63,
#  '4474_lc.jpg': 2.88,
#  '4474_rc.jpg': 3.0,
#  '4483_chin.jpg': 2.43,
#  '4483_fh.jpg': 2.26,
#  '4483_lc.jpg': 2.69,
#  '4483_rc.jpg': 2.32,
#  '4564_chin.jpg': 2.66,
#  '4564_fh.jpg': 2.85,
#  '4564_lc.jpg': 2.92,
#  '4564_rc.jpg': 2.58,
#  '4605_chin.jpg': 3.83,
#  '4605_fh.jpg': 3.65,
#  '4605_lc.jpg': 3.52,
#  '4605_rc.jpg': 4.01,
#  '4629_chin.jpg': 3.12,
#  '4629_fh.jpg': 2.34,
#  '4629_lc.jpg': 2.66,
#  '4629_rc.jpg': 3.11}

# %% [markdown]
# ## Infer Image Label
#
# After each skin patch image is predicted, we need to infer the predicted label of the entire selfie from the predicted skin patch labels. In this application, we choose to maximal predicted skin patch label as the predicted label of the entire selfie. This logic can be modified further to balance the performance of the model on the entire 5 levels of the acne severity.

# %%
# get the max score value among the patches and record the image name
image_patch_scores = {}
for key in patch_score:
    image_id = key[0:4]
    image_patch_scores_i = image_patch_scores.get(image_id, {"patch_name":[], "patch_score":[]})
    image_patch_scores_i["patch_name"].append(key)
    image_patch_scores_i["patch_score"].append(patch_score[key])
    image_patch_scores[image_id] = image_patch_scores_i

fp = open(result_file, 'w')
fp.write("Image_Name, Predicted_Label_Avg, Most_Severe_Patch\n")

for key in image_patch_scores:
    image_name = key + ".jpg"
    max_index = np.argmax(image_patch_scores[key]['patch_score'])
    Predicted_Label_Avg = np.mean(image_patch_scores[key]['patch_score'])
    Most_Severe_Patch = image_patch_scores[key]['patch_name'][max_index]
    fp.write('%s, %.4f, %s\n'%(image_name, Predicted_Label_Avg, Most_Severe_Patch))

fp.close()

# %% [markdown]
# ## (Optional) Calculate RMSE on Test Images

# %%
if test_ground_truth is not None:
    fp = open(test_ground_truth, 'r')
    fp.readline()
    ground_truth = {}
    for row in fp:
        row = row.strip().split(',')
        ground_truth[row[0]] = float(row[1])
    fp.close()
    
    fp = open(result_file, 'r')
    fp.readline()
    num_images = 0.0
    RMSE = 0.0
    for row in fp:
        row = row.strip().split(',')
        RMSE += (ground_truth[row[0]] - float(row[1]))**2
        num_images += 1.0
    fp.close()
    RMSE = np.sqrt(RMSE/num_images)
print("RMSE=%.4f"%RMSE)
# Out:
# RMSE=0.4819
